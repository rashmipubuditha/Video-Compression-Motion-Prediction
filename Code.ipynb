# %% [markdown]
# <font size="6">Created by : Rashmi Pubuditha <br>Date : 2024/01/03</font>

# %%
import cv2
import numpy as np
from moviepy.editor import VideoFileClip
import huffman
import os

# %% [markdown]
# <font size="5">Functions</font>

# %%
def motion_estimation(prev_frame, curr_frame, block_size):
    '''
    Calculate the motion vector using the previous frame and current frame. By analysing the search area find the best match by lowest MSE. 
    '''
    height, width = prev_frame.shape[:2]

    # Initialize the motion vectors
    motion_vectors = np.zeros((height // block_size, width // block_size, 2), dtype=int)


    for y in range(0, height, block_size):
        for x in range(0, width, block_size):
            # Define the search window
            search_area = curr_frame[y:y+block_size, x:x+block_size]

            # Search for the best match in the search window
            min_mse = float('inf')
            best_match = (0, 0)

            for dy in range(-block_size, block_size + 1):
                for dx in range(-block_size, block_size + 1):
                    # Define the current block in the previous frame
                    block = prev_frame[y+dy:y+dy+block_size, x+dx:x+dx+block_size]

                    # Check if the shapes of search_area and block are non-empty
                    if search_area.shape[0] > 0 and search_area.shape[1] > 0 and block.shape[0] > 0 and block.shape[1] > 0:
                        # Check if the shapes of search_area and block are compatible
                        if search_area.shape == block.shape:
                            # Calculate Mean Squared Error (MSE) as the matching criteria
                            mse = np.sum((search_area - block) ** 2)

                            # Update the best match if the current MSE is smaller
                            if mse < min_mse:
                                min_mse = mse
                                best_match = (dy, dx)

            # Update the motion vector for the current block
            motion_row = min(y // block_size, motion_vectors.shape[0] - 1)
            motion_col = min(x // block_size, motion_vectors.shape[1] - 1)
            motion_vectors[motion_row, motion_col] = best_match

    return motion_vectors


def motion_compensation(reference_frame, motion_vectors, block_size):
    '''
    Return the predicted image by motion compensation. 
    This predicted frame is used to get the residual frame. (Residual = Reference - predicted)
    '''
    height, width = reference_frame.shape[:2]
    predicted_frame = np.zeros_like(reference_frame)

    for y in range(0, height, block_size):
        for x in range(0, width, block_size):
            # Get the motion vector for the current block
            # dy, dx = motion_vectors[y // block_size, x // block_size]

            motion_row = min(y // block_size, motion_vectors.shape[0] - 1)
            motion_col = min(x // block_size, motion_vectors.shape[1] - 1)
            dy, dx = motion_vectors[motion_row, motion_col]

            # Apply motion compensation to predict the current block in the current frame
            predicted_block = reference_frame[y+dy:y+dy+block_size, x+dx:x+dx+block_size]

            # Update the predicted frame with the compensated block
            predicted_frame[y:y+block_size, x:x+block_size] = predicted_block

    return predicted_frame


def combine(inv_dct_blocks, height, width, block_size):
    ''' 
    Use to combine all the macroblocks after quantization. Reshaped into original image array size
    '''
    reconstructed_image_arr = np.zeros((height, width), dtype=np.float32)

    for i, (row, col) in enumerate([(i, j) for i in range(0, height, block_size) for j in range(0, width, block_size)]):
        reconstructed_image_arr[row:row + block_size, col:col + block_size] = inv_dct_blocks[i]

    return reconstructed_image_arr


def calculate_probabilities(data):
    ''' 
    Calculate the probabilities after combine all the macroblocks. for construct the one huffman mapping for one image.
    '''
    unique_values, counts = np.unique(data, return_counts=True)
    probabilities = counts / len(data)
    return zip(unique_values, probabilities/8)


def encode_with_huffman(data, huffman_mappings):
    ''' 
    Encode data using huffman mappings
    '''
    encoded_data = ""
    for value in data:
        encoded_data += huffman_mappings[value]
    return encoded_data

def decode_with_huffman(encoded_data, huffman_mappings):
    ''' 
    Decode the data using huffman mappings
    '''
    reverse_mappings = {v: k for k, v in huffman_mappings.items()}
            
    decoded_data = []
    current_code = ""
            
    for bit in encoded_data:
        current_code += bit
        if current_code in reverse_mappings:
            decoded_data.append(reverse_mappings[current_code])
            current_code = ""
            
    return decoded_data

def combine_and_convert_to_uint8(inv_dct_blocks, height, width, block_size):
    ''' 
    After decoding combine each blocks and reconstruct the frame in to oringinal frame array size
    '''
    reconstructed_image = np.zeros((height, width), dtype=np.float32)

    for i, (row, col) in enumerate([(i, j) for i in range(0, height, block_size) for j in range(0, width, block_size)]):
        reconstructed_image[row:row + block_size, col:col + block_size] = inv_dct_blocks[i]

    # Convert the reconstructed image back to uint8
    reconstructed_image = np.clip(reconstructed_image, 0, 255).astype(np.uint8)

    return reconstructed_image


def encode_frames(frame, block_size, quantization_matrix, output_file_path):
    ''' 
    Take frame --> devide into macroblocks --> Apply DCT --> Quantize --> combine blocks --> Calculate probabilities -->Take huffman mapping -->
    -->Encode data --> Save encode data into text file

    Apply this function to encode a frame
    '''
    height, width = frame.shape[:2]
    
    # Divide the frame into 8x8 macro blocks
    macro_blocks = [frame[i:i + block_size, j:j + block_size] for i in range(0, height, block_size) for j in range(0, width, block_size)]

    # Apply DCT to each macro block
    dct_macro_blocks = [cv2.dct(np.float32(block)) for block in macro_blocks]

    # Quantize the DCT coefficients using the given quantization matrix
    quantized_block = [np.round(dct_block / quantization_matrix) for dct_block in dct_macro_blocks]

    # combine again blocks and flattern
    re_img = combine(quantized_block, height, width, block_size)
    flat_re_img = re_img.flatten()
    # Take probalities and mapping huffman
    prob_re_img = list(calculate_probabilities(flat_re_img))
    huffman_mappings = huffman.codebook(prob_re_img)

    # Encode the flattened image using Huffman mappings
    encoded_data = encode_with_huffman(flat_re_img, huffman_mappings)
    
    # Write the encoded data to a text file
    with open(output_file_path, 'w') as output_file:
        output_file.write(encoded_data)

    return prob_re_img, huffman_mappings,encoded_data


def decode_frames(input_file_path,huffman_mappings,block_size, height,width, quantization_matrix):
    ''' 
    Read the text file --> Decode data --> Remake macroblocks --> Dequantized --> Apply inverse DCT --> Combine blocks and reconstruct the frame

    Apply this function to reconstruct a frame by reading the encoded file
    '''
    # Read the encoded data from the text file
    with open(input_file_path, 'r') as input_file:
        encoded_data_re = input_file.read()

    decoded_data = decode_with_huffman(encoded_data_re, huffman_mappings)
    decoded_img = np.array(decoded_data).reshape(height, width)
    macro_blocks_re = [decoded_img[i:i + block_size, j:j + block_size] for i in range(0, height, block_size) for j in range(0, width, block_size)]
    dequantized_blocks = [np.multiply(block, quantization_matrix) for block in macro_blocks_re]
    inv_dct_blocks = [cv2.idct(np.float32(block)) for block in dequantized_blocks]
    # reconstructed_image= combine_and_convert_to_uint8(inv_dct_blocks, height, width, block_size)
    reconstructed_image= combine(inv_dct_blocks, height, width, block_size)

    return reconstructed_image

def mv_encode(motion_vectors, output_file_path_mv):
    ''' 
    Encode the motion vector. Apply huffman for encoding. Save a text file
    '''
    flat_mv = motion_vectors.flatten()
    prob_mv = list(calculate_probabilities(flat_mv))
    huffman_mappings_mv = huffman.codebook(prob_mv)
    encoded_data_mv = encode_with_huffman(flat_mv, huffman_mappings_mv)
    
    # Write the encoded data to a text file
    with open(output_file_path_mv, 'w') as output_file:
        output_file.write(encoded_data_mv)

    return huffman_mappings_mv, encoded_data_mv

def mv_decode(input_file_path_mv,huffman_mappings_mv,height,width,block_size):
    ''' 
    Decode the motion vector by reading the encoded text file.
    '''
    size = (height // block_size, width // block_size, 2)
    with open(input_file_path_mv, 'r') as input_file:
        encoded_data_mv = input_file.read()
    
    decoded_data_mv = decode_with_huffman(encoded_data_mv, huffman_mappings_mv)
    decoded_mv = np.array(decoded_data_mv).reshape(size)

    return decoded_mv


def reconstruct_frame(i_frame, motion_vectors, residual_frame, block_size):
    ''' 
    Reconstruct the frame, Take reconstructed I frame as the first frame and predict next 9 frames using motion vectors and residual frame.
    This is the final output of Inter frame prediction
    '''
    height, width = i_frame.shape
    reconstructed_frame = np.copy(i_frame)

    for i in range(0, height, block_size):
        for j in range(0, width, block_size):
            # Extract motion vector for the current block
            mv_x, mv_y = motion_vectors[i // block_size, j // block_size]

            # Calculate the new position for the block based on motion vectors
            new_i = i + mv_y
            new_j = j + mv_x

            # Check if the new position is within the valid range
            if 0 <= new_i < height - block_size and 0 <= new_j < width - block_size:
                # Extract the corresponding block from the residual frame
                block_residual = residual_frame[i:i + block_size, j:j + block_size]

                # Update the reconstructed frame with the predicted block
                reconstructed_frame[i:i + block_size, j:j + block_size] = i_frame[new_i:new_i + block_size, new_j:new_j + block_size] + block_residual

    return reconstructed_frame


def calculate_average_length(probability, huffman_code):
    ''' 
    Average length = sum of (probability of symbol * len(huffman mapping))
    '''
    average_length = 0.0

    for symbol, prob in probability:
        code = huffman_code[symbol]
        average_length += len(code) * prob

    return average_length


def compression_ratio(height, width, avg_length):
    ''' 
    Compression ratio = size befor compression/ size after compression
    '''
    input_image_size = height*width*8
    compressed_size = height*width*avg_length
    compression_ratio = input_image_size /compressed_size
    return compression_ratio


def intra_predict(curr_frame,height, width):
    ''' 
    Function for Intra frame predintion. Intra-frame prediction by using the average of neighboring pixels
    '''
    predicted_image = np.zeros_like(curr_frame)

    for i in range(1, height):
        for j in range(1, width):
            # Predict the pixel value as the average of its neighbors
            predicted_image[i, j] = (curr_frame[i-1, j] + curr_frame[i, j-1] + curr_frame[i-1, j-1]) // 3

    return predicted_image

# %%
# Quantization matrix

quantization_matrix = np.array([[16, 11, 10, 16, 24, 40, 51, 61],
                                            [12, 12, 14, 19, 26, 58, 60, 55],
                                            [14, 13, 16, 24, 40, 57, 69, 56],
                                            [14, 17, 22, 29, 51, 87, 80, 62],
                                            [18, 22, 37, 56, 68, 109, 103, 77],
                                            [24, 35, 55, 64, 81, 104, 113, 92],
                                            [49, 64, 78, 87, 103, 121, 120, 101],
                                            [72, 92, 95, 98, 112, 100, 103, 99]])

# %% [markdown]
# <font size="5">Compress frames using Inter prediction <br>Used IPPPPPPPPPI pattern </font>

# %%
# Read the video
video_path = 'input_video.mp4'
cap = cv2.VideoCapture(video_path)

fps = cap.get(cv2.CAP_PROP_FPS)
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

# Create a folder to save frames
output_folder1 = 'motionvector'
os.makedirs(output_folder1, exist_ok=True)

# Create a folder to save frames
output_folder2 = 'inter_predicted'
os.makedirs(output_folder2, exist_ok=True)

# Create a folder to save frames
output_folder3 = 'inter_residual'
os.makedirs(output_folder3, exist_ok=True)

# Create a folder to save frames
output_folder4 = 'inter_reconstructed'
os.makedirs(output_folder4, exist_ok=True)

# Create a folder to save frames
output_folder5 = 'i_frames'
os.makedirs(output_folder5, exist_ok=True)

# Create a folder to save text files
output_folder6 = 'all_text_files'
os.makedirs(output_folder6, exist_ok=True)

# Create a folder to save frames
output_folder8 = 'original_frames'
os.makedirs(output_folder8, exist_ok=True)

# Set the block size for macroblock search
block_size = 8
frame_counter = 0
i_frame_interval = 10  # (IPPPPPPPPPI pattern)
i_no = -1

# Make arrays to save data
original_frame_i = []
processed_frame_i_arr = []
video_arr = []
huffman_mappings_arr = []
huffman_mapping_mv_arr = []
current_bitrate_arr = []

while True:
    # Read the current frame
    ret, curr_frame = cap.read()
    if not ret:
        print('finished the process. Total number of frames =',frame_counter)
        break

    # for I frames (0,10, 20,30,... frames)
    if frame_counter % i_frame_interval == 0:

        # Convert to grayscale 
        curr_frame_gray = cv2.cvtColor(curr_frame, cv2.COLOR_BGR2GRAY)
        cv2.imwrite(os.path.join(output_folder8, f'original_frame_{frame_counter}.png'), curr_frame_gray)
        original_frame_i.append(curr_frame_gray) # original frame array

        # Encode data and save text files
        output_file_path = os.path.join(output_folder6, f'text_i{frame_counter}.txt')
        prob_i, huffman_mappings, encoded_i = encode_frames(curr_frame_gray, block_size=8, quantization_matrix = quantization_matrix , output_file_path=output_file_path) # reconstructed i frame
          
        # Read the text files and decode data
        processed_frame_i = decode_frames(output_file_path,huffman_mappings, block_size, height,width, quantization_matrix)   # Decoded i frame
        cv2.imwrite(os.path.join(output_folder5, f'i_frames_{frame_counter}.png'), processed_frame_i)

        # calculate average length , compression ratio and bitrate
        average_len = calculate_average_length(prob_i, huffman_mappings)
        cr = compression_ratio(height, width, average_len)
        current_bitrate = len(encoded_i)*fps
        current_bitrate_arr.append(current_bitrate)

        # print information  
        print(f'saved I frame {frame_counter}, CR = {cr} , Bitrate {current_bitrate/1000} kbps')

        processed_frame_i_arr.append(processed_frame_i)  # reconstructed i frame array
        i_no += 1
        video_arr.append(processed_frame_i_arr[i_no])  # array of the video frames
        huffman_mappings_arr.append(huffman_mappings) # huffman mappings of frames


    # for predition frames (Inter prediction - P frames)
    elif frame_counter % i_frame_interval != 0:
            
        # Convert to grayscale for motion estimation
        curr_frame_gray = cv2.cvtColor(curr_frame, cv2.COLOR_BGR2GRAY)
        cv2.imwrite(os.path.join(output_folder8, f'original_frame_{frame_counter}.png'), curr_frame_gray)

        # Perform motion estimation to get motion vectors
        motion_vectors = motion_estimation(prev_frame, curr_frame_gray, block_size)

        # Visualize the motion vectors (optional)
        for y in range(0, motion_vectors.shape[0]):
            for x in range(0, motion_vectors.shape[1]):
                dx, dy = motion_vectors[y, x]
                cv2.arrowedLine(curr_frame, (x * block_size + block_size // 2, y * block_size + block_size // 2),
                                (x * block_size + block_size // 2 + dx, y * block_size + block_size // 2 + dy),
                                color=(0, 255, 0), thickness=1)
                    
            # Save the frame with motion vectors
            cv2.imwrite(os.path.join(output_folder1, f'motion_vector_{frame_counter}.png'), curr_frame)


        # Encode and save text files of motion vectors              
        output_file_path_mv = os.path.join(output_folder6, f'text_mv{frame_counter}.txt')
        huffman_mapping_mv,encoded_mv = mv_encode(motion_vectors, output_file_path_mv)
        huffman_mapping_mv_arr.append(huffman_mapping_mv)  # huffman mapping of motion vectors

        # Perform motion compensation to predict the current frame
        predicted_frame = motion_compensation(prev_frame, motion_vectors , block_size)
        cv2.imwrite(os.path.join(output_folder2, f'inter_predicted_frame_{frame_counter}.png'), predicted_frame)

        # take the residual frame
        residual = cv2.absdiff(original_frame_i[i_no], predicted_frame)
        cv2.imwrite(os.path.join(output_folder3, f'inter_residual_frame_{frame_counter}.png'), residual)

        # encode the residual and save text files
        output_file_path_res = os.path.join(output_folder6, f'text_residual{frame_counter}.txt')
        prob_i,huffman_mappings,encoded_i = encode_frames(residual, block_size=8, quantization_matrix = quantization_matrix, output_file_path=output_file_path_res)   
        huffman_mappings_arr.append(huffman_mappings) # huffman mapping of frames

        # Decoding files

        # Decoding motionvector
        motion_vectors_decode = mv_decode(output_file_path_mv, huffman_mapping_mv, height,width,block_size)  
        # Decoding residual
        processed_frame_res = decode_frames(output_file_path_res,huffman_mappings, block_size, height,width, quantization_matrix)

        # Reconstruct the frame and save png
        final_predicted_image = reconstruct_frame(processed_frame_i_arr[i_no], motion_vectors_decode, processed_frame_res, block_size)
        cv2.imwrite(os.path.join(output_folder4, f'reconstructed_{frame_counter}.png'), final_predicted_image)

        # calculate average length, compression ratio and bitrate
        average_len = calculate_average_length(prob_i, huffman_mappings)
        cr = compression_ratio(height, width, average_len)
        current_bitrate = (len(encoded_i)+len(encoded_mv))*fps
        current_bitrate_arr.append(current_bitrate)

        print(f'saved predicted frame {frame_counter}, CR = {cr} , Bitrate {current_bitrate/1000} kbps')
        
        video_arr.append(final_predicted_image)

    prev_frame = curr_frame_gray

    frame_counter += 1         

# Release the video capture and close the window
cap.release()
cv2.destroyAllWindows()
# Out:
# saved I frame 0, CR = 47.583182473837574 , Bitrate 7747.275 kbps
# saved predicted frame 1, CR = 62.29210407364069 , Bitrate 6200.825 kbps
# saved predicted frame 2, CR = 61.204871286142385 , Bitrate 6283.075 kbps
# saved predicted frame 3, CR = 60.29909094998379 , Bitrate 6374.85 kbps
# saved predicted frame 4, CR = 59.55556273576905 , Bitrate 6462.325 kbps
# saved predicted frame 5, CR = 58.94891701513543 , Bitrate 6557.0 kbps
# saved predicted frame 6, CR = 58.39633438808122 , Bitrate 6576.5 kbps
# saved predicted frame 7, CR = 57.96203631275032 , Bitrate 6643.375 kbps
# saved predicted frame 8, CR = 57.55054250253683 , Bitrate 6662.15 kbps
# saved predicted frame 9, CR = 57.127139032771645 , Bitrate 6697.55 kbps
# saved I frame 10, CR = 47.644373216841785 , Bitrate 7737.325 kbps
# saved predicted frame 11, CR = 62.69680979977806 , Bitrate 6139.9 kbps
# saved predicted frame 12, CR = 61.99146574737773 , Bitrate 6184.275 kbps
# saved predicted frame 13, CR = 61.28372649743156 , Bitrate 6249.025 kbps
# saved predicted frame 14, CR = 60.7002161160852 , Bitrate 6312.125 kbps
# saved predicted frame 15, CR = 60.153467709365884 , Bitrate 6380.5 kbps
# saved predicted frame 16, CR = 59.75394291086498 , Bitrate 6404.45 kbps
# saved predicted frame 17, CR = 59.36423073206858 , Bitrate 6441.5 kbps
# saved predicted frame 18, CR = 59.09917997963969 , Bitrate 6472.05 kbps
# saved predicted frame 19, CR = 58.87665752308845 , Bitrate 6499.225 kbps
# saved I frame 20, CR = 47.775894971828095 , Bitrate 7716.025 kbps
# saved predicted frame 21, CR = 63.392216122334005 , Bitrate 6043.0 kbps
# saved predicted frame 22, CR = 62.92771608784345 , Bitrate 6076.0 kbps
# saved predicted frame 23, CR = 62.592484113744355 , Bitrate 6113.525 kbps
# saved predicted frame 24, CR = 62.385398729919686 , Bitrate 6117.025 kbps
# saved predicted frame 25, CR = 62.15006448676126 , Bitrate 6148.975 kbps
# saved predicted frame 26, CR = 62.00606368976787 , Bitrate 6149.65 kbps
# saved predicted frame 27, CR = 61.83471157555727 , Bitrate 6178.05 kbps
# saved predicted frame 28, CR = 61.72160482200035 , Bitrate 6196.825 kbps
# saved predicted frame 29, CR = 61.34593623111229 , Bitrate 6242.625 kbps
# saved I frame 30, CR = 47.81012904480898 , Bitrate 7710.5 kbps
# saved predicted frame 31, CR = 62.91670755695128 , Bitrate 6095.8 kbps
# saved predicted frame 32, CR = 62.11079660331583 , Bitrate 6176.775 kbps
# saved predicted frame 33, CR = 61.386031447352565 , Bitrate 6254.35 kbps
# saved predicted frame 34, CR = 60.93751937151568 , Bitrate 6282.75 kbps
# saved predicted frame 35, CR = 60.43278688524585 , Bitrate 6346.625 kbps
# saved predicted frame 36, CR = 59.992188517120134 , Bitrate 6390.55 kbps
# saved predicted frame 37, CR = 59.47413212440459 , Bitrate 6454.775 kbps
# saved predicted frame 38, CR = 58.91500123858306 , Bitrate 6505.15 kbps
# saved predicted frame 39, CR = 58.26757340941331 , Bitrate 6588.7 kbps
# saved I frame 40, CR = 47.71235908520248 , Bitrate 7726.3 kbps
# saved predicted frame 41, CR = 62.51340729780947 , Bitrate 6159.25 kbps
# saved predicted frame 42, CR = 61.28933039610957 , Bitrate 6265.65 kbps
# saved predicted frame 43, CR = 60.32746107206269 , Bitrate 6356.0 kbps
# saved predicted frame 44, CR = 59.544259633905504 , Bitrate 6439.7 kbps
# saved predicted frame 45, CR = 58.74834658719663 , Bitrate 6524.45 kbps
# saved predicted frame 46, CR = 58.18939492594915 , Bitrate 6576.15 kbps
# saved predicted frame 47, CR = 57.72514631329637 , Bitrate 6632.4 kbps
# saved predicted frame 48, CR = 57.216026820012544 , Bitrate 6687.9 kbps
# saved predicted frame 49, CR = 56.65849516241819 , Bitrate 6754.425 kbps
# saved I frame 50, CR = 47.77821700051194 , Bitrate 7715.65 kbps
# saved predicted frame 51, CR = 62.68828038312906 , Bitrate 6120.275 kbps
# saved predicted frame 52, CR = 61.52202937249663 , Bitrate 6234.675 kbps
# saved predicted frame 53, CR = 60.30402296735248 , Bitrate 6362.15 kbps
# saved predicted frame 54, CR = 59.32673235458602 , Bitrate 6460.95 kbps
# saved predicted frame 55, CR = 58.48272360948059 , Bitrate 6555.175 kbps
# saved predicted frame 56, CR = 57.848341120670355 , Bitrate 6630.25 kbps
# saved predicted frame 57, CR = 57.29094222184229 , Bitrate 6704.95 kbps
# saved predicted frame 58, CR = 57.004128717005024 , Bitrate 6727.35 kbps
# saved predicted frame 59, CR = 56.629337757500245 , Bitrate 6782.7 kbps
# saved I frame 60, CR = 47.70973471943156 , Bitrate 7726.725 kbps
# saved predicted frame 61, CR = 61.38909820607077 , Bitrate 6292.775 kbps
# saved predicted frame 62, CR = 59.87720495078454 , Bitrate 6436.4 kbps
# saved predicted frame 63, CR = 58.60964267260223 , Bitrate 6586.575 kbps
# saved predicted frame 64, CR = 57.737803899149895 , Bitrate 6679.8 kbps
# saved predicted frame 65, CR = 56.951729145584956 , Bitrate 6774.075 kbps
# saved predicted frame 66, CR = 56.343280730579615 , Bitrate 6838.275 kbps
# saved predicted frame 67, CR = 55.860470049853745 , Bitrate 6905.475 kbps
# saved predicted frame 68, CR = 55.621734784330734 , Bitrate 6917.25 kbps
# saved predicted frame 69, CR = 55.393770004057174 , Bitrate 6946.6 kbps
# saved I frame 70, CR = 47.500257705391185 , Bitrate 7760.8 kbps
# saved predicted frame 71, CR = 60.87739144076819 , Bitrate 6363.325 kbps
# saved predicted frame 72, CR = 59.296910814962565 , Bitrate 6509.975 kbps
# saved predicted frame 73, CR = 58.10570118058732 , Bitrate 6661.15 kbps
# saved predicted frame 74, CR = 57.517991925574854 , Bitrate 6705.125 kbps
# saved predicted frame 75, CR = 56.95788880047584 , Bitrate 6762.85 kbps
# saved predicted frame 76, CR = 56.57480269644984 , Bitrate 6801.325 kbps
# saved predicted frame 77, CR = 56.16237483479524 , Bitrate 6864.225 kbps
# saved predicted frame 78, CR = 55.87401670279033 , Bitrate 6874.8 kbps
# saved predicted frame 79, CR = 55.56891282310242 , Bitrate 6908.425 kbps
# saved I frame 80, CR = 47.65669186491837 , Bitrate 7735.325 kbps
# saved predicted frame 81, CR = 62.06635294513804 , Bitrate 6216.8 kbps
# saved predicted frame 82, CR = 60.6315789473684 , Bitrate 6324.925 kbps
# saved predicted frame 83, CR = 59.3943592759379 , Bitrate 6479.1 kbps
# saved predicted frame 84, CR = 58.73500814569036 , Bitrate 6516.825 kbps
# saved predicted frame 85, CR = 58.139379004435675 , Bitrate 6622.475 kbps
# saved predicted frame 86, CR = 57.6146287143219 , Bitrate 6638.05 kbps
# saved predicted frame 87, CR = 57.07119966559839 , Bitrate 6701.1 kbps
# saved predicted frame 88, CR = 56.74833167848148 , Bitrate 6722.075 kbps
# saved predicted frame 89, CR = 56.43730336734611 , Bitrate 6758.3 kbps
# saved I frame 90, CR = 47.77032302374321 , Bitrate 7716.925 kbps
# saved predicted frame 91, CR = 63.019693654266945 , Bitrate 6080.5 kbps
# saved predicted frame 92, CR = 62.14508780876356 , Bitrate 6154.225 kbps
# saved predicted frame 93, CR = 61.26972123307305 , Bitrate 6256.05 kbps
# saved predicted frame 94, CR = 60.43452066247801 , Bitrate 6320.425 kbps
# saved predicted frame 95, CR = 59.59816827461325 , Bitrate 6419.3 kbps
# saved predicted frame 96, CR = 58.973200180771755 , Bitrate 6465.575 kbps
# saved predicted frame 97, CR = 58.40998217468805 , Bitrate 6533.475 kbps
# saved predicted frame 98, CR = 58.01676889845408 , Bitrate 6574.7 kbps
# saved predicted frame 99, CR = 57.507448949347165 , Bitrate 6626.3 kbps
# finished the process. Total number of frames = 100

# %% [markdown]
# <font size="5">Reconstruct the video </font>

# %%
# Define the codec and create a VideoWriter object
fourcc = cv2.VideoWriter_fourcc(*'H264')
out = cv2.VideoWriter('Reconstructed_video_inter_prediction1.mp4', fourcc, fps, (width, height), isColor=False)  # isColor=False for grayscale video

# Write each frame to the video
for frame in video_arr:
    out.write(frame)

# Release the VideoWriter object
out.release()

# %% [markdown]
# <font size="5">Get the output video using transmitted files (This code, Decoding text files  reconstruct the video)</font>

# %%
fps = 25 
width = 640 
height = 360 

# Video writer to save the processed video
output_path = "Transmit_reconstructed_video.mp4"

fourcc = cv2.VideoWriter_fourcc(*'H264')
out = cv2.VideoWriter(output_path, fourcc, fps, (width, height), isColor=False)  # isColor=False for grayscale video

# Create a folder to save frames
output_folder1 = 'Transmit_reconstructed'
os.makedirs(output_folder1, exist_ok=True)

# Set the block size for macroblock search
block_size = 8
frame_counter = 0
i_frame_interval = 10
i_no = -1
total_frames = 100

folder_name = 'all_text_files'

frame_i_arr = []
video_arr_decoded = []
mv=0

while frame_counter < total_frames:

    if frame_counter % i_frame_interval == 0:
        
        # Decode I frames
        input_file_path = os.path.join(folder_name, f'text_i{frame_counter}.txt')
        frame_i = decode_frames(input_file_path,huffman_mappings_arr[frame_counter], block_size, height,width, quantization_matrix)  # Decoded I frames
        frame_i_arr.append(frame_i) # I frame array
        i_no += 1
        video_arr_decoded.append(frame_i_arr[i_no])
 

    elif frame_counter % i_frame_interval != 0:
            
            # Decode motion vectors
            input_file_path_mv = os.path.join(folder_name, f'text_mv{frame_counter}.txt')
            mv_decodes = mv_decode(input_file_path_mv, huffman_mapping_mv_arr[mv], height,width,block_size)  # Decoded motion vectors

            # Decode residuals
            input_file_path_res = os.path.join(folder_name, f'text_residual{frame_counter}.txt')
            frame_res = decode_frames(input_file_path_res,huffman_mappings_arr[frame_counter], block_size, height,width, quantization_matrix) # Decoded residuals
            
            # reconstructed frames and save
            predicted_image = reconstruct_frame(frame_i_arr[i_no], mv_decodes, frame_res, block_size)
            cv2.imwrite(os.path.join(output_folder1, f'm_reconstructed_{frame_counter}.png'), predicted_image)

            print(f'Saved reconstructed frame {frame_counter}')
            video_arr_decoded.append(predicted_image)
            mv += 1 

    frame_counter += 1  

# Write each frame to the video
for frame in video_arr_decoded:
    out.write(frame)       

# Release the video capture and close the window
out.release()
print('Reconstructed video is saved')

cap.release()
cv2.destroyAllWindows()
# Out:
# Saved reconstructed frame 1
# Saved reconstructed frame 2
# Saved reconstructed frame 3
# Saved reconstructed frame 4
# Saved reconstructed frame 5
# Saved reconstructed frame 6
# Saved reconstructed frame 7
# Saved reconstructed frame 8
# Saved reconstructed frame 9
# Saved reconstructed frame 11
# Saved reconstructed frame 12
# Saved reconstructed frame 13
# Saved reconstructed frame 14
# Saved reconstructed frame 15
# Saved reconstructed frame 16
# Saved reconstructed frame 17
# Saved reconstructed frame 18
# Saved reconstructed frame 19
# Saved reconstructed frame 21
# Saved reconstructed frame 22
# Saved reconstructed frame 23
# Saved reconstructed frame 24
# Saved reconstructed frame 25
# Saved reconstructed frame 26
# Saved reconstructed frame 27
# Saved reconstructed frame 28
# Saved reconstructed frame 29
# Saved reconstructed frame 31
# Saved reconstructed frame 32
# Saved reconstructed frame 33
# Saved reconstructed frame 34
# Saved reconstructed frame 35
# Saved reconstructed frame 36
# Saved reconstructed frame 37
# Saved reconstructed frame 38
# Saved reconstructed frame 39
# Saved reconstructed frame 41
# Saved reconstructed frame 42
# Saved reconstructed frame 43
# Saved reconstructed frame 44
# Saved reconstructed frame 45
# Saved reconstructed frame 46
# Saved reconstructed frame 47
# Saved reconstructed frame 48
# Saved reconstructed frame 49
# Saved reconstructed frame 51
# Saved reconstructed frame 52
# Saved reconstructed frame 53
# Saved reconstructed frame 54
# Saved reconstructed frame 55
# Saved reconstructed frame 56
# Saved reconstructed frame 57
# Saved reconstructed frame 58
# Saved reconstructed frame 59
# Saved reconstructed frame 61
# Saved reconstructed frame 62
# Saved reconstructed frame 63
# Saved reconstructed frame 64
# Saved reconstructed frame 65
# Saved reconstructed frame 66
# Saved reconstructed frame 67
# Saved reconstructed frame 68
# Saved reconstructed frame 69
# Saved reconstructed frame 71
# Saved reconstructed frame 72
# Saved reconstructed frame 73
# Saved reconstructed frame 74
# Saved reconstructed frame 75
# Saved reconstructed frame 76
# Saved reconstructed frame 77
# Saved reconstructed frame 78
# Saved reconstructed frame 79
# Saved reconstructed frame 81
# Saved reconstructed frame 82
# Saved reconstructed frame 83
# Saved reconstructed frame 84
# Saved reconstructed frame 85
# Saved reconstructed frame 86
# Saved reconstructed frame 87
# Saved reconstructed frame 88
# Saved reconstructed frame 89
# Saved reconstructed frame 91
# Saved reconstructed frame 92
# Saved reconstructed frame 93
# Saved reconstructed frame 94
# Saved reconstructed frame 95
# Saved reconstructed frame 96
# Saved reconstructed frame 97
# Saved reconstructed frame 98
# Saved reconstructed frame 99
# Reconstructed video is saved

# %% [markdown]
# <font size="5">Adjust the compression ratio of all the frame for transmit in a fixed bitrate<br>The fixed bitrate is taken as = 6500 kbps</font>

# %%
# Read the video
video_path = 'input_video.mp4'
cap = cv2.VideoCapture(video_path)

fps = cap.get(cv2.CAP_PROP_FPS)
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

# Create a folder to save frames
output_folder3 = 'adjust_output_frames_residual'
os.makedirs(output_folder3, exist_ok=True)

# Create a folder to save frames
output_folder4 = 'adjust_reconstructed'
os.makedirs(output_folder4, exist_ok=True)

# Create a folder to save frames
output_folder1 = 'adjust_i_frames'
os.makedirs(output_folder1, exist_ok=True)

# Create a folder to save frames
output_folder7 = 'adjust_text_files'
os.makedirs(output_folder7, exist_ok=True)

# Set the block size for macroblock search
block_size = 8
frame_counter = 0
i_frame_interval = 10
i_no = -1
target_bitrate = 6500000  # fixed bitrate is taken as 6500 kbps 

original_frame_i = []
processed_frame_i_arr = []
adjust_video_arr = []
huffman_mappings_i_arr = []
huffman_mapping_mv_arr = []

while True:
    # Read the current frame
    ret, curr_frame = cap.read()
    if not ret:
        print('finished the process. Total number of frames =',frame_counter)
        break

    current_bitrate = current_bitrate_arr[frame_counter]

    # for I frames (0,10,20,30,..)
    if frame_counter % i_frame_interval == 0:

        # Convert to grayscale for motion estimation
        curr_frame_gray = cv2.cvtColor(curr_frame, cv2.COLOR_BGR2GRAY)

        original_frame_i.append(curr_frame_gray)

        # if current bitrate is greater that target bitrate reduse the quality by multiply Quantizaiton matrix by a factor
        if current_bitrate > target_bitrate:
            factor = 1
            # this loop is running until the target bitrate achived
            while current_bitrate > target_bitrate:
                factor += 0.1
                quantization_matrix1 = np.copy(quantization_matrix)
                quantization_matrix_re = np.round(quantization_matrix1 * factor).astype(int) 
                output_file_path = os.path.join(output_folder7, f'text_i_adjust_{frame_counter}.txt')
                prob_i, huffman_mappings_i, encoded_i = encode_frames(curr_frame_gray, block_size=8, quantization_matrix = quantization_matrix_re , output_file_path=output_file_path) # reconstructed i frame
      
                processed_frame_i = decode_frames(output_file_path,huffman_mappings_i, block_size, height,width, quantization_matrix)   # Decoded i frame

                average_len = calculate_average_length(prob_i, huffman_mappings_i)
                cr = compression_ratio(height, width, average_len)
                current_bitrate = len(encoded_i)*fps
                print('CR = ',cr, ', Bitrate', current_bitrate/1000,'kbps')

        # if current bitrate is less than target bitrate no need to reduse quality
        else:
            output_file_path = os.path.join(output_folder7, f'text_i_adjust_{frame_counter}.txt')
            prob_i, huffman_mappings_i, encoded_i = encode_frames(curr_frame_gray, block_size=8, quantization_matrix = quantization_matrix , output_file_path=output_file_path) # reconstructed i frame
                
            processed_frame_i = decode_frames(output_file_path,huffman_mappings_i, block_size, height,width, quantization_matrix)   # Decoded i frame

            average_len = calculate_average_length(prob_i, huffman_mappings_i)
            cr = compression_ratio(height, width, average_len)
            current_bitrate = len(encoded_i)*fps
            print('CR = ',cr, ', Bitrate', current_bitrate/1000,'kbps')

        print(f"saved i frame {frame_counter}, Adjusted compression ratio is {cr}. Target bitrate: {target_bitrate/1000} kbps, Current bitrate : {current_bitrate/1000} kbps")
        cv2.imwrite(os.path.join(output_folder1, f'i_frames_adjust_{frame_counter}.png'), processed_frame_i)
        processed_frame_i_arr.append(processed_frame_i)
        adjust_video_arr.append(processed_frame_i)
        huffman_mappings_i_arr.append(huffman_mappings_i)
        i_no += 1

    # For P frames
    elif frame_counter % i_frame_interval != 0:
            
        # Convert to grayscale for motion estimation
        curr_frame_gray = cv2.cvtColor(curr_frame, cv2.COLOR_BGR2GRAY)
        
        # Perform motion estimation to get motion vectors
        motion_vectors = motion_estimation(prev_frame, curr_frame_gray, block_size)
                        
        output_file_path_mv = os.path.join(output_folder6, f'text_mv{frame_counter}.txt')
        huffman_mapping_mv,encoded_mv = mv_encode(motion_vectors, output_file_path_mv)
        huffman_mapping_mv_arr.append(huffman_mapping_mv)

        motion_vectors_decode = mv_decode(output_file_path_mv, huffman_mapping_mv, height,width,block_size)  # Decodeed motion vector

        # Perform motion compensation to predict the current frame
        predicted_frame = motion_compensation(prev_frame, motion_vectors_decode , block_size)

        residual = cv2.absdiff(original_frame_i[i_no], predicted_frame)
        cv2.imwrite(os.path.join(output_folder3, f'Residual_frame_{frame_counter}.png'), residual)

        # if current bitrate is greater that target bitrate reduse the quality by multiply Quantizaiton matrix by a factor
        if current_bitrate > target_bitrate:
            factor = 1
            while current_bitrate > target_bitrate:
                factor += 0.1
                quantization_matrix2 = np.copy(quantization_matrix)
                quantization_matrix_res = np.round(quantization_matrix2 * factor).astype(int) 

                output_file_path_res = os.path.join(output_folder6, f'text_residual{frame_counter}.txt')
                prob_i,huffman_mappings_i,encoded_i = encode_frames(residual, block_size=8, quantization_matrix = quantization_matrix_res, output_file_path=output_file_path_res)   
                huffman_mappings_i_arr.append(huffman_mappings_i)
                processed_frame_res = decode_frames(output_file_path_res,huffman_mappings_i, block_size, height,width, quantization_matrix)  # Decoded residual

                average_len = calculate_average_length(prob_i, huffman_mappings_i)
                cr = compression_ratio(height, width, average_len)
                current_bitrate = (len(encoded_i)+len(encoded_mv))*fps
                print('CR = ',cr, ', Bitrate', current_bitrate/1000,'kbps')
                
        # if current bitrate is less than target bitrate no need to reduse quality
        else:
                output_file_path_res = os.path.join(output_folder6, f'text_residual{frame_counter}.txt')

                prob_i,huffman_mappings_i,encoded_i = encode_frames(residual, block_size=8, quantization_matrix = quantization_matrix, output_file_path=output_file_path_res)   
                huffman_mappings_i_arr.append(huffman_mappings_i)
                processed_frame_res = decode_frames(output_file_path_res,huffman_mappings_i, block_size, height,width, quantization_matrix)  # Decoded residual

                average_len = calculate_average_length(prob_i, huffman_mappings_i)
                cr = compression_ratio(height, width, average_len)
                current_bitrate = (len(encoded_i)+len(encoded_mv))*fps
                print('CR = ',cr, ', Bitrate', current_bitrate/1000,'kbps')
        
        print(f"saved predicted frame {frame_counter}, Adjusted compression ratio is {cr}. Target bitrate: {target_bitrate/1000} kbps, Current bitrate : {current_bitrate/1000} kbps")

        # Get the final predicted images using compressed i frames, motion vectors and residuals
        final_predicted_image = reconstruct_frame(processed_frame_i_arr[i_no], motion_vectors, processed_frame_res, block_size)
        
        # Save the predicted image
        cv2.imwrite(os.path.join(output_folder4, f'reconstructed_{frame_counter}.png'), final_predicted_image)

        adjust_video_arr.append(final_predicted_image)

    prev_frame = curr_frame_gray

    frame_counter += 1        

# Release the video capture and close the window
cap.release()
cv2.destroyAllWindows()
# Out:
# CR =  48.18713297408233 , Bitrate 7650.175 kbps
# CR =  48.75416600539596 , Bitrate 7561.2 kbps
# CR =  49.33833444308004 , Bitrate 7471.675 kbps
# CR =  49.796196799259775 , Bitrate 7402.975 kbps
# CR =  50.31219931623231 , Bitrate 7327.05 kbps
# CR =  50.68993255367861 , Bitrate 7272.45 kbps
# CR =  51.06082379624979 , Bitrate 7219.625 kbps
# CR =  51.43951524284955 , Bitrate 7166.475 kbps
# CR =  51.74039973051878 , Bitrate 7124.8 kbps
# CR =  52.01123072364803 , Bitrate 7087.7 kbps
# CR =  52.27731196709976 , Bitrate 7051.625 kbps
# CR =  52.51525177447675 , Bitrate 7019.675 kbps
# CR =  52.81337526235483 , Bitrate 6980.05 kbps
# CR =  53.02074718636512 , Bitrate 6952.75 kbps
# CR =  53.27745059074323 , Bitrate 6919.25 kbps
# CR =  53.46928859186952 , Bitrate 6894.425 kbps
# CR =  53.64435729435344 , Bitrate 6871.925 kbps
# CR =  53.87504567044209 , Bitrate 6842.5 kbps
# CR =  54.04307877250787 , Bitrate 6821.225 kbps
# CR =  54.20937311589194 , Bitrate 6800.3 kbps
# CR =  54.37910039349028 , Bitrate 6779.075 kbps
# CR =  54.511779906322666 , Bitrate 6762.575 kbps
# CR =  54.70410162046653 , Bitrate 6738.8 kbps
# CR =  54.831032841504054 , Bitrate 6723.2 kbps
# CR =  54.98499114384268 , Bitrate 6704.375 kbps
# CR =  55.123326180738836 , Bitrate 6687.55 kbps
# CR =  55.219107392955294 , Bitrate 6675.95 kbps
# CR =  55.37130497476571 , Bitrate 6657.6 kbps
# CR =  55.47483700579744 , Bitrate 6645.175 kbps
# CR =  55.5775000376909 , Bitrate 6632.9 kbps
# CR =  55.67717989284139 , Bitrate 6621.025 kbps
# CR =  55.80106942967535 , Bitrate 6606.325 kbps
# CR =  55.922754268463805 , Bitrate 6591.95 kbps
# CR =  56.0345351735879 , Bitrate 6578.8 kbps
# CR =  56.148901818624886 , Bitrate 6565.4 kbps
# CR =  56.23862973260561 , Bitrate 6554.925 kbps
# CR =  56.343065442415494 , Bitrate 6542.775 kbps
# CR =  56.43924750732017 , Bitrate 6531.625 kbps
# CR =  56.527306043901284 , Bitrate 6521.45 kbps
# CR =  56.624118704207184 , Bitrate 6510.3 kbps
# CR =  56.71842725758616 , Bitrate 6499.475 kbps
# saved i frame 0, Adjusted compression ratio is 56.71842725758616. Target bitrate: 6500.0 kbps, Current bitrate : 6499.475 kbps
# CR =  62.29210407364069 , Bitrate 6200.825 kbps
# saved predicted frame 1, Adjusted compression ratio is 62.29210407364069. Target bitrate: 6500.0 kbps, Current bitrate : 6200.825 kbps
# CR =  61.204871286142385 , Bitrate 6283.075 kbps
# saved predicted frame 2, Adjusted compression ratio is 61.204871286142385. Target bitrate: 6500.0 kbps, Current bitrate : 6283.075 kbps
# CR =  60.29909094998379 , Bitrate 6374.85 kbps
# saved predicted frame 3, Adjusted compression ratio is 60.29909094998379. Target bitrate: 6500.0 kbps, Current bitrate : 6374.85 kbps
# CR =  59.55556273576905 , Bitrate 6462.325 kbps
# saved predicted frame 4, Adjusted compression ratio is 59.55556273576905. Target bitrate: 6500.0 kbps, Current bitrate : 6462.325 kbps
# CR =  59.35347794410654 , Bitrate 6514.375 kbps
# CR =  59.69467688458682 , Bitrate 6478.875 kbps
# saved predicted frame 5, Adjusted compression ratio is 59.69467688458682. Target bitrate: 6500.0 kbps, Current bitrate : 6478.875 kbps
# CR =  58.83202534322267 , Bitrate 6529.75 kbps
# CR =  59.204773127868215 , Bitrate 6490.3 kbps
# saved predicted frame 6, Adjusted compression ratio is 59.204773127868215. Target bitrate: 6500.0 kbps, Current bitrate : 6490.3 kbps
# CR =  58.41761846468342 , Bitrate 6593.775 kbps
# CR =  58.78816390645311 , Bitrate 6554.0 kbps
# CR =  59.17839885701442 , Bitrate 6512.65 kbps
# CR =  59.48132939093113 , Bitrate 6480.925 kbps
# saved predicted frame 7, Adjusted compression ratio is 59.48132939093113. Target bitrate: 6500.0 kbps, Current bitrate : 6480.925 kbps
# CR =  58.01973653146983 , Bitrate 6610.35 kbps
# CR =  58.4305815874878 , Bitrate 6565.675 kbps
# CR =  58.84517305643233 , Bitrate 6521.225 kbps
# CR =  59.127143246667835 , Bitrate 6491.35 kbps
# saved predicted frame 8, Adjusted compression ratio is 59.127143246667835. Target bitrate: 6500.0 kbps, Current bitrate : 6491.35 kbps
# CR =  57.62701266218536 , Bitrate 6641.575 kbps
# CR =  58.03594973177419 , Bitrate 6596.5 kbps
# CR =  58.48017228045544 , Bitrate 6548.25 kbps
# CR =  58.80762374223806 , Bitrate 6513.15 kbps
# CR =  59.16985008506948 , Bitrate 6474.775 kbps
# saved predicted frame 9, Adjusted compression ratio is 59.16985008506948. Target bitrate: 6500.0 kbps, Current bitrate : 6474.775 kbps
# CR =  48.25320365982956 , Bitrate 7639.7 kbps
# CR =  48.820347108641975 , Bitrate 7550.95 kbps
# CR =  49.41737128379398 , Bitrate 7459.725 kbps
# CR =  49.881432819260304 , Bitrate 7390.325 kbps
# CR =  50.36013975266648 , Bitrate 7320.075 kbps
# CR =  50.734755247883164 , Bitrate 7266.025 kbps
# CR =  51.06789727960658 , Bitrate 7218.625 kbps
# CR =  51.45207945873712 , Bitrate 7164.725 kbps
# CR =  51.74820757398693 , Bitrate 7123.725 kbps
# CR =  52.02958279229945 , Bitrate 7085.2 kbps
# CR =  52.292328642759884 , Bitrate 7049.6 kbps
# CR =  52.539951185619366 , Bitrate 7016.375 kbps
# CR =  52.843847319927875 , Bitrate 6976.025 kbps
# CR =  53.05279518748516 , Bitrate 6948.55 kbps
# CR =  53.320604890325626 , Bitrate 6913.65 kbps
# CR =  53.49955192093492 , Bitrate 6890.525 kbps
# CR =  53.68693543630463 , Bitrate 6866.475 kbps
# CR =  53.91325967254831 , Bitrate 6837.65 kbps
# CR =  54.064280528851455 , Bitrate 6818.55 kbps
# CR =  54.21595049617797 , Bitrate 6799.475 kbps
# CR =  54.382309227098204 , Bitrate 6778.675 kbps
# CR =  54.516616816832375 , Bitrate 6761.975 kbps
# CR =  54.71587493599117 , Bitrate 6737.35 kbps
# CR =  54.84836875053466 , Bitrate 6721.075 kbps
# CR =  55.013710895965076 , Bitrate 6700.875 kbps
# CR =  55.15611031521304 , Bitrate 6683.575 kbps
# CR =  55.262566147480776 , Bitrate 6670.7 kbps
# CR =  55.414587216643596 , Bitrate 6652.4 kbps
# CR =  55.50887654153677 , Bitrate 6641.1 kbps
# CR =  55.62194459532863 , Bitrate 6627.6 kbps
# CR =  55.730207982947135 , Bitrate 6614.725 kbps
# CR =  55.8450264159518 , Bitrate 6601.125 kbps
# CR =  55.957558232200164 , Bitrate 6587.85 kbps
# CR =  56.07416928424205 , Bitrate 6574.15 kbps
# CR =  56.18184727693912 , Bitrate 6561.55 kbps
# CR =  56.26030156889078 , Bitrate 6552.4 kbps
# CR =  56.365464226874685 , Bitrate 6540.175 kbps
# CR =  56.45912862355604 , Bitrate 6529.325 kbps
# CR =  56.55180348616462 , Bitrate 6518.625 kbps
# CR =  56.65152947142755 , Bitrate 6507.15 kbps
# CR =  56.73435780628381 , Bitrate 6497.65 kbps
# saved i frame 10, Adjusted compression ratio is 56.73435780628381. Target bitrate: 6500.0 kbps, Current bitrate : 6497.65 kbps
# CR =  62.69680979977806 , Bitrate 6139.9 kbps
# saved predicted frame 11, Adjusted compression ratio is 62.69680979977806. Target bitrate: 6500.0 kbps, Current bitrate : 6139.9 kbps
# CR =  61.99146574737773 , Bitrate 6184.275 kbps
# saved predicted frame 12, Adjusted compression ratio is 61.99146574737773. Target bitrate: 6500.0 kbps, Current bitrate : 6184.275 kbps
# CR =  61.28372649743156 , Bitrate 6249.025 kbps
# saved predicted frame 13, Adjusted compression ratio is 61.28372649743156. Target bitrate: 6500.0 kbps, Current bitrate : 6249.025 kbps
# CR =  60.7002161160852 , Bitrate 6312.125 kbps
# saved predicted frame 14, Adjusted compression ratio is 60.7002161160852. Target bitrate: 6500.0 kbps, Current bitrate : 6312.125 kbps
# CR =  60.153467709365884 , Bitrate 6380.5 kbps
# saved predicted frame 15, Adjusted compression ratio is 60.153467709365884. Target bitrate: 6500.0 kbps, Current bitrate : 6380.5 kbps
# CR =  59.75394291086498 , Bitrate 6404.45 kbps
# saved predicted frame 16, Adjusted compression ratio is 59.75394291086498. Target bitrate: 6500.0 kbps, Current bitrate : 6404.45 kbps
# CR =  59.36423073206858 , Bitrate 6441.5 kbps
# saved predicted frame 17, Adjusted compression ratio is 59.36423073206858. Target bitrate: 6500.0 kbps, Current bitrate : 6441.5 kbps
# CR =  59.09917997963969 , Bitrate 6472.05 kbps
# saved predicted frame 18, Adjusted compression ratio is 59.09917997963969. Target bitrate: 6500.0 kbps, Current bitrate : 6472.05 kbps
# CR =  58.87665752308845 , Bitrate 6499.225 kbps
# saved predicted frame 19, Adjusted compression ratio is 58.87665752308845. Target bitrate: 6500.0 kbps, Current bitrate : 6499.225 kbps
# CR =  48.38684272701023 , Bitrate 7618.6 kbps
# CR =  48.94577513410165 , Bitrate 7531.6 kbps
# CR =  49.54172826233033 , Bitrate 7441.0 kbps
# CR =  49.976783517314125 , Bitrate 7376.225 kbps
# CR =  50.46786547926266 , Bitrate 7304.45 kbps
# CR =  50.84742255954374 , Bitrate 7249.925 kbps
# CR =  51.18649245338032 , Bitrate 7201.9 kbps
# CR =  51.5776991930491 , Bitrate 7147.275 kbps
# CR =  51.882397646827016 , Bitrate 7105.3 kbps
# CR =  52.165238032907524 , Bitrate 7066.775 kbps
# CR =  52.438122332859194 , Bitrate 7030.0 kbps
# CR =  52.66567851849207 , Bitrate 6999.625 kbps
# CR =  52.94516834406316 , Bitrate 6962.675 kbps
# CR =  53.1411272884532 , Bitrate 6937.0 kbps
# CR =  53.40422218439552 , Bitrate 6902.825 kbps
# CR =  53.58626328699917 , Bitrate 6879.375 kbps
# CR =  53.76523651001425 , Bitrate 6856.475 kbps
# CR =  53.99617702848187 , Bitrate 6827.15 kbps
# CR =  54.155220284702715 , Bitrate 6807.1 kbps
# CR =  54.29000618538482 , Bitrate 6790.2 kbps
# CR =  54.46909111057752 , Bitrate 6767.875 kbps
# CR =  54.59877366035724 , Bitrate 6751.8 kbps
# CR =  54.790082079597525 , Bitrate 6728.225 kbps
# CR =  54.912095810167166 , Bitrate 6713.275 kbps
# CR =  55.06877247756444 , Bitrate 6694.175 kbps
# CR =  55.2031896374221 , Bitrate 6677.875 kbps
# CR =  55.301944959083116 , Bitrate 6665.95 kbps
# CR =  55.46210901650443 , Bitrate 6646.7 kbps
# CR =  55.568284594513116 , Bitrate 6634.0 kbps
# CR =  55.67696966493229 , Bitrate 6621.05 kbps
# CR =  55.781860000605285 , Bitrate 6608.6 kbps
# CR =  55.90324904272663 , Bitrate 6594.25 kbps
# CR =  56.017718277862436 , Bitrate 6580.775 kbps
# CR =  56.12368403023591 , Bitrate 6568.35 kbps
# CR =  56.23541256693058 , Bitrate 6555.3 kbps
# CR =  56.310575799466896 , Bitrate 6546.55 kbps
# CR =  56.41959625950813 , Bitrate 6533.9 kbps
# CR =  56.520805863052324 , Bitrate 6522.2 kbps
# CR =  56.605642291465905 , Bitrate 6512.425 kbps
# CR =  56.69618311218428 , Bitrate 6502.025 kbps
# CR =  56.78679534478905 , Bitrate 6491.65 kbps
# saved i frame 20, Adjusted compression ratio is 56.78679534478905. Target bitrate: 6500.0 kbps, Current bitrate : 6491.65 kbps
# CR =  63.392216122334005 , Bitrate 6043.0 kbps
# saved predicted frame 21, Adjusted compression ratio is 63.392216122334005. Target bitrate: 6500.0 kbps, Current bitrate : 6043.0 kbps
# CR =  62.92771608784345 , Bitrate 6076.0 kbps
# saved predicted frame 22, Adjusted compression ratio is 62.92771608784345. Target bitrate: 6500.0 kbps, Current bitrate : 6076.0 kbps
# CR =  62.592484113744355 , Bitrate 6113.525 kbps
# saved predicted frame 23, Adjusted compression ratio is 62.592484113744355. Target bitrate: 6500.0 kbps, Current bitrate : 6113.525 kbps
# CR =  62.385398729919686 , Bitrate 6117.025 kbps
# saved predicted frame 24, Adjusted compression ratio is 62.385398729919686. Target bitrate: 6500.0 kbps, Current bitrate : 6117.025 kbps
# CR =  62.15006448676126 , Bitrate 6148.975 kbps
# saved predicted frame 25, Adjusted compression ratio is 62.15006448676126. Target bitrate: 6500.0 kbps, Current bitrate : 6148.975 kbps
# CR =  62.00606368976787 , Bitrate 6149.65 kbps
# saved predicted frame 26, Adjusted compression ratio is 62.00606368976787. Target bitrate: 6500.0 kbps, Current bitrate : 6149.65 kbps
# CR =  61.83471157555727 , Bitrate 6178.05 kbps
# saved predicted frame 27, Adjusted compression ratio is 61.83471157555727. Target bitrate: 6500.0 kbps, Current bitrate : 6178.05 kbps
# CR =  61.72160482200035 , Bitrate 6196.825 kbps
# saved predicted frame 28, Adjusted compression ratio is 61.72160482200035. Target bitrate: 6500.0 kbps, Current bitrate : 6196.825 kbps
# CR =  61.34593623111229 , Bitrate 6242.625 kbps
# saved predicted frame 29, Adjusted compression ratio is 61.34593623111229. Target bitrate: 6500.0 kbps, Current bitrate : 6242.625 kbps
# CR =  48.42307136570819 , Bitrate 7612.9 kbps
# CR =  48.98610040662291 , Bitrate 7525.4 kbps
# CR =  49.55987779424667 , Bitrate 7438.275 kbps
# CR =  50.01611168962444 , Bitrate 7370.425 kbps
# CR =  50.493442454542375 , Bitrate 7300.75 kbps
# CR =  50.86355875200498 , Bitrate 7247.625 kbps
# CR =  51.20853475579262 , Bitrate 7198.8 kbps
# CR =  51.601704939144334 , Bitrate 7143.95 kbps
# CR =  51.900293544140744 , Bitrate 7102.85 kbps
# CR =  52.1724362421806 , Bitrate 7065.8 kbps
# CR =  52.436071135197395 , Bitrate 7030.275 kbps
# CR =  52.67790797370676 , Bitrate 6998.0 kbps
# CR =  52.97217681820632 , Bitrate 6959.125 kbps
# CR =  53.173512770860164 , Bitrate 6932.775 kbps
# CR =  53.43131393288471 , Bitrate 6899.325 kbps
# CR =  53.6098366139013 , Bitrate 6876.35 kbps
# CR =  53.80133175225762 , Bitrate 6851.875 kbps
# CR =  54.021497812850306 , Bitrate 6823.95 kbps
# CR =  54.1846723696975 , Bitrate 6803.4 kbps
# CR =  54.3294118513988 , Bitrate 6785.275 kbps
# CR =  54.504526149649415 , Bitrate 6763.475 kbps
# CR =  54.6270912674303 , Bitrate 6748.3 kbps
# CR =  54.8167644369103 , Bitrate 6724.95 kbps
# CR =  54.93480366589673 , Bitrate 6710.5 kbps
# CR =  55.09572703223782 , Bitrate 6690.9 kbps
# CR =  55.23606886528117 , Bitrate 6673.9 kbps
# CR =  55.330789233730734 , Bitrate 6662.475 kbps
# CR =  55.49153830811319 , Bitrate 6643.175 kbps
# CR =  55.60558408941783 , Bitrate 6629.55 kbps
# CR =  55.70389174731975 , Bitrate 6617.85 kbps
# CR =  55.81775647868455 , Bitrate 6604.35 kbps
# CR =  55.93017830930463 , Bitrate 6591.075 kbps
# CR =  56.0338963728601 , Bitrate 6578.875 kbps
# CR =  56.14141960243824 , Bitrate 6566.275 kbps
# CR =  56.24914170621178 , Bitrate 6553.7 kbps
# CR =  56.3279993582422 , Bitrate 6544.525 kbps
# CR =  56.42607318062493 , Bitrate 6533.15 kbps
# CR =  56.516040013797884 , Bitrate 6522.75 kbps
# CR =  56.5976033838194 , Bitrate 6513.35 kbps
# CR =  56.693349327550806 , Bitrate 6502.35 kbps
# CR =  56.77367687486043 , Bitrate 6493.15 kbps
# saved i frame 30, Adjusted compression ratio is 56.77367687486043. Target bitrate: 6500.0 kbps, Current bitrate : 6493.15 kbps
# CR =  62.91670755695128 , Bitrate 6095.8 kbps
# saved predicted frame 31, Adjusted compression ratio is 62.91670755695128. Target bitrate: 6500.0 kbps, Current bitrate : 6095.8 kbps
# CR =  62.11079660331583 , Bitrate 6176.775 kbps
# saved predicted frame 32, Adjusted compression ratio is 62.11079660331583. Target bitrate: 6500.0 kbps, Current bitrate : 6176.775 kbps
# CR =  61.386031447352565 , Bitrate 6254.35 kbps
# saved predicted frame 33, Adjusted compression ratio is 61.386031447352565. Target bitrate: 6500.0 kbps, Current bitrate : 6254.35 kbps
# CR =  60.93751937151568 , Bitrate 6282.75 kbps
# saved predicted frame 34, Adjusted compression ratio is 60.93751937151568. Target bitrate: 6500.0 kbps, Current bitrate : 6282.75 kbps
# CR =  60.43278688524585 , Bitrate 6346.625 kbps
# saved predicted frame 35, Adjusted compression ratio is 60.43278688524585. Target bitrate: 6500.0 kbps, Current bitrate : 6346.625 kbps
# CR =  59.992188517120134 , Bitrate 6390.55 kbps
# saved predicted frame 36, Adjusted compression ratio is 59.992188517120134. Target bitrate: 6500.0 kbps, Current bitrate : 6390.55 kbps
# CR =  59.47413212440459 , Bitrate 6454.775 kbps
# saved predicted frame 37, Adjusted compression ratio is 59.47413212440459. Target bitrate: 6500.0 kbps, Current bitrate : 6454.775 kbps
# CR =  59.32267486301422 , Bitrate 6462.15 kbps
# saved predicted frame 38, Adjusted compression ratio is 59.32267486301422. Target bitrate: 6500.0 kbps, Current bitrate : 6462.15 kbps
# CR =  58.721441912142396 , Bitrate 6539.8 kbps
# CR =  59.11789822272649 , Bitrate 6497.7 kbps
# saved predicted frame 39, Adjusted compression ratio is 59.11789822272649. Target bitrate: 6500.0 kbps, Current bitrate : 6497.7 kbps
# CR =  48.31438953345503 , Bitrate 7630.025 kbps
# CR =  48.89254356879492 , Bitrate 7539.8 kbps
# CR =  49.47374425010653 , Bitrate 7451.225 kbps
# CR =  49.93582601569297 , Bitrate 7382.275 kbps
# CR =  50.43144577942395 , Bitrate 7309.725 kbps
# CR =  50.800825458291314 , Bitrate 7256.575 kbps
# CR =  51.144415964594046 , Bitrate 7207.825 kbps
# CR =  51.53875997441514 , Bitrate 7152.675 kbps
# CR =  51.83406742900124 , Bitrate 7111.925 kbps
# CR =  52.126881104641896 , Bitrate 7071.975 kbps
# CR =  52.38335452975906 , Bitrate 7037.35 kbps
# CR =  52.617943969254796 , Bitrate 7005.975 kbps
# CR =  52.90831392782943 , Bitrate 6967.525 kbps
# CR =  53.112798420908554 , Bitrate 6940.7 kbps
# CR =  53.36614671926462 , Bitrate 6907.75 kbps
# CR =  53.5506504259909 , Bitrate 6883.95 kbps
# CR =  53.733105461276956 , Bitrate 6860.575 kbps
# CR =  53.98392080483839 , Bitrate 6828.7 kbps
# CR =  54.1405062454563 , Bitrate 6808.95 kbps
# CR =  54.30500160201521 , Bitrate 6788.325 kbps
# CR =  54.467682715109945 , Bitrate 6768.05 kbps
# CR =  54.60807477798434 , Bitrate 6750.65 kbps
# CR =  54.80942929146501 , Bitrate 6725.85 kbps
# CR =  54.92436799505347 , Bitrate 6711.775 kbps
# CR =  55.073503047687346 , Bitrate 6693.6 kbps
# CR =  55.20587640676599 , Bitrate 6677.55 kbps
# CR =  55.31127974102846 , Bitrate 6664.825 kbps
# CR =  55.45772860103275 , Bitrate 6647.225 kbps
# CR =  55.563049908623356 , Bitrate 6634.625 kbps
# CR =  55.68285664655192 , Bitrate 6620.35 kbps
# CR =  55.79114642451756 , Bitrate 6607.5 kbps
# CR =  55.90282516718988 , Bitrate 6594.3 kbps
# CR =  56.000698793442 , Bitrate 6582.775 kbps
# CR =  56.11279182601743 , Bitrate 6569.625 kbps
# CR =  56.2216901279568 , Bitrate 6556.9 kbps
# CR =  56.30219052237295 , Bitrate 6547.525 kbps
# CR =  56.39650734520753 , Bitrate 6536.575 kbps
# CR =  56.48573070293043 , Bitrate 6526.25 kbps
# CR =  56.56894263156681 , Bitrate 6516.65 kbps
# CR =  56.66698691466674 , Bitrate 6505.375 kbps
# CR =  56.75750577367205 , Bitrate 6495.0 kbps
# saved i frame 40, Adjusted compression ratio is 56.75750577367205. Target bitrate: 6500.0 kbps, Current bitrate : 6495.0 kbps
# CR =  62.51340729780947 , Bitrate 6159.25 kbps
# saved predicted frame 41, Adjusted compression ratio is 62.51340729780947. Target bitrate: 6500.0 kbps, Current bitrate : 6159.25 kbps
# CR =  61.28933039610957 , Bitrate 6265.65 kbps
# saved predicted frame 42, Adjusted compression ratio is 61.28933039610957. Target bitrate: 6500.0 kbps, Current bitrate : 6265.65 kbps
# CR =  60.32746107206269 , Bitrate 6356.0 kbps
# saved predicted frame 43, Adjusted compression ratio is 60.32746107206269. Target bitrate: 6500.0 kbps, Current bitrate : 6356.0 kbps
# CR =  59.544259633905504 , Bitrate 6439.7 kbps
# saved predicted frame 44, Adjusted compression ratio is 59.544259633905504. Target bitrate: 6500.0 kbps, Current bitrate : 6439.7 kbps
# CR =  59.18885071128093 , Bitrate 6477.75 kbps
# saved predicted frame 45, Adjusted compression ratio is 59.18885071128093. Target bitrate: 6500.0 kbps, Current bitrate : 6477.75 kbps
# CR =  58.64787253506002 , Bitrate 6526.625 kbps
# CR =  59.039786672645796 , Bitrate 6484.9 kbps
# saved predicted frame 46, Adjusted compression ratio is 59.039786672645796. Target bitrate: 6500.0 kbps, Current bitrate : 6484.9 kbps
# CR =  58.211907196349074 , Bitrate 6579.0 kbps
# CR =  58.60940971656375 , Bitrate 6536.05 kbps
# CR =  59.02253532402029 , Bitrate 6492.025 kbps
# saved predicted frame 47, Adjusted compression ratio is 59.02253532402029. Target bitrate: 6500.0 kbps, Current bitrate : 6492.025 kbps
# CR =  57.70029934847679 , Bitrate 6633.825 kbps
# CR =  58.14396403856388 , Bitrate 6585.075 kbps
# CR =  58.604983903660425 , Bitrate 6535.2 kbps
# CR =  58.92394744413538 , Bitrate 6501.15 kbps
# CR =  59.263308080300604 , Bitrate 6465.325 kbps
# saved predicted frame 48, Adjusted compression ratio is 59.263308080300604. Target bitrate: 6500.0 kbps, Current bitrate : 6465.325 kbps
# CR =  57.19649659045943 , Bitrate 6693.225 kbps
# CR =  57.645035183737214 , Bitrate 6643.075 kbps
# CR =  58.1441933092538 , Bitrate 6588.175 kbps
# CR =  58.475997858545 , Bitrate 6552.2 kbps
# CR =  58.81583355935982 , Bitrate 6515.775 kbps
# CR =  59.09278532298334 , Bitrate 6486.4 kbps
# saved predicted frame 49, Adjusted compression ratio is 59.09278532298334. Target bitrate: 6500.0 kbps, Current bitrate : 6486.4 kbps
# CR =  48.372874238925 , Bitrate 7620.8 kbps
# CR =  48.948699733772436 , Bitrate 7531.15 kbps
# CR =  49.55771247277715 , Bitrate 7438.6 kbps
# CR =  49.98660976097578 , Bitrate 7374.775 kbps
# CR =  50.47097480832421 , Bitrate 7304.0 kbps
# CR =  50.84286418663348 , Bitrate 7250.575 kbps
# CR =  51.19217897265695 , Bitrate 7201.1 kbps
# CR =  51.59809362512158 , Bitrate 7144.45 kbps
# CR =  51.88641401879029 , Bitrate 7104.75 kbps
# CR =  52.177051523847574 , Bitrate 7065.175 kbps
# CR =  52.44539605421804 , Bitrate 7029.025 kbps
# CR =  52.68129559631586 , Bitrate 6997.55 kbps
# CR =  52.974841117869175 , Bitrate 6958.775 kbps
# CR =  53.170444998142955 , Bitrate 6933.175 kbps
# CR =  53.434218250603315 , Bitrate 6898.95 kbps
# CR =  53.621533560732225 , Bitrate 6874.85 kbps
# CR =  53.79662092893446 , Bitrate 6852.475 kbps
# CR =  54.0442672159447 , Bitrate 6821.075 kbps
# CR =  54.20339506399748 , Bitrate 6801.05 kbps
# CR =  54.35324300016217 , Bitrate 6782.3 kbps
# CR =  54.5139967170933 , Bitrate 6762.3 kbps
# CR =  54.645715979839906 , Bitrate 6746.0 kbps
# CR =  54.842248942809434 , Bitrate 6721.825 kbps
# CR =  54.956096542882264 , Bitrate 6707.9 kbps
# CR =  55.12085348804174 , Bitrate 6687.85 kbps
# CR =  55.2507634374356 , Bitrate 6672.125 kbps
# CR =  55.35280581696968 , Bitrate 6659.825 kbps
# CR =  55.49968383969167 , Bitrate 6642.2 kbps
# CR =  55.621315167083495 , Bitrate 6627.675 kbps
# CR =  55.7365275798593 , Bitrate 6613.975 kbps
# CR =  55.83064824525867 , Bitrate 6602.825 kbps
# CR =  55.95437314299376 , Bitrate 6588.225 kbps
# CR =  56.05157523415643 , Bitrate 6576.8 kbps
# CR =  56.15724149487578 , Bitrate 6564.425 kbps
# CR =  56.26008691438666 , Bitrate 6552.425 kbps
# CR =  56.332518337408324 , Bitrate 6544.0 kbps
# CR =  56.42888030828929 , Bitrate 6532.825 kbps
# CR =  56.51972264491574 , Bitrate 6522.325 kbps
# CR =  56.606076892070874 , Bitrate 6512.375 kbps
# CR =  56.70185153140683 , Bitrate 6501.375 kbps
# CR =  56.7837338262477 , Bitrate 6492.0 kbps
# saved i frame 50, Adjusted compression ratio is 56.7837338262477. Target bitrate: 6500.0 kbps, Current bitrate : 6492.0 kbps
# CR =  62.68828038312906 , Bitrate 6120.275 kbps
# saved predicted frame 51, Adjusted compression ratio is 62.68828038312906. Target bitrate: 6500.0 kbps, Current bitrate : 6120.275 kbps
# CR =  61.52202937249663 , Bitrate 6234.675 kbps
# saved predicted frame 52, Adjusted compression ratio is 61.52202937249663. Target bitrate: 6500.0 kbps, Current bitrate : 6234.675 kbps
# CR =  60.30402296735248 , Bitrate 6362.15 kbps
# saved predicted frame 53, Adjusted compression ratio is 60.30402296735248. Target bitrate: 6500.0 kbps, Current bitrate : 6362.15 kbps
# CR =  59.32673235458602 , Bitrate 6460.95 kbps
# saved predicted frame 54, Adjusted compression ratio is 59.32673235458602. Target bitrate: 6500.0 kbps, Current bitrate : 6460.95 kbps
# CR =  58.929599079225035 , Bitrate 6507.375 kbps
# CR =  59.297626180777 , Bitrate 6468.55 kbps
# saved predicted frame 55, Adjusted compression ratio is 59.297626180777. Target bitrate: 6500.0 kbps, Current bitrate : 6468.55 kbps
# CR =  58.30904712381416 , Bitrate 6579.9 kbps
# CR =  58.7055446514239 , Bitrate 6537.2 kbps
# CR =  59.13994882366624 , Bitrate 6491.075 kbps
# saved predicted frame 56, Adjusted compression ratio is 59.13994882366624. Target bitrate: 6500.0 kbps, Current bitrate : 6491.075 kbps
# CR =  57.793246166870425 , Bitrate 6649.025 kbps
# CR =  58.22776812509866 , Bitrate 6601.425 kbps
# CR =  58.6691069687867 , Bitrate 6553.8 kbps
# CR =  58.99089468883518 , Bitrate 6519.525 kbps
# CR =  59.29977238178732 , Bitrate 6486.975 kbps
# saved predicted frame 57, Adjusted compression ratio is 59.29977238178732. Target bitrate: 6500.0 kbps, Current bitrate : 6486.975 kbps
# CR =  57.48323717448928 , Bitrate 6673.45 kbps
# CR =  57.91832454152309 , Bitrate 6625.275 kbps
# CR =  58.360279421368205 , Bitrate 6577.075 kbps
# CR =  58.68825446860337 , Bitrate 6541.775 kbps
# CR =  59.021117853311786 , Bitrate 6506.35 kbps
# CR =  59.28070048483971 , Bitrate 6479.0 kbps
# saved predicted frame 58, Adjusted compression ratio is 59.28070048483971. Target bitrate: 6500.0 kbps, Current bitrate : 6479.0 kbps
# CR =  57.159470177111494 , Bitrate 6722.325 kbps
# CR =  57.60045000351563 , Bitrate 6672.95 kbps
# CR =  58.05994361583163 , Bitrate 6622.3 kbps
# CR =  58.39078457072936 , Bitrate 6586.325 kbps
# CR =  58.74694225544016 , Bitrate 6548.05 kbps
# CR =  59.030096317824835 , Bitrate 6517.95 kbps
# CR =  59.259973716889895 , Bitrate 6493.725 kbps
# saved predicted frame 59, Adjusted compression ratio is 59.259973716889895. Target bitrate: 6500.0 kbps, Current bitrate : 6493.725 kbps
# CR =  48.310115716775705 , Bitrate 7630.7 kbps
# CR =  48.873907466515526 , Bitrate 7542.675 kbps
# CR =  49.48270944143357 , Bitrate 7449.875 kbps
# CR =  49.92585068562723 , Bitrate 7383.75 kbps
# CR =  50.402313387430866 , Bitrate 7313.95 kbps
# CR =  50.77808349374815 , Bitrate 7259.825 kbps
# CR =  51.129519377802104 , Bitrate 7209.925 kbps
# CR =  51.5371387828713 , Bitrate 7152.9 kbps
# CR =  51.857765336015525 , Bitrate 7108.675 kbps
# CR =  52.13830851752193 , Bitrate 7070.425 kbps
# CR =  52.4064399189679 , Bitrate 7034.25 kbps
# CR =  52.64330391568843 , Bitrate 7002.6 kbps
# CR =  52.923885305740086 , Bitrate 6965.475 kbps
# CR =  53.13327640070479 , Bitrate 6938.025 kbps
# CR =  53.390686609965165 , Bitrate 6904.575 kbps
# CR =  53.580616560805794 , Bitrate 6880.1 kbps
# CR =  53.768177243622524 , Bitrate 6856.1 kbps
# CR =  54.006262933323555 , Bitrate 6825.875 kbps
# CR =  54.163575054547096 , Bitrate 6806.05 kbps
# CR =  54.31460301674122 , Bitrate 6787.125 kbps
# CR =  54.484588269200934 , Bitrate 6765.95 kbps
# CR =  54.629115077689136 , Bitrate 6748.05 kbps
# CR =  54.8033181696548 , Bitrate 6726.6 kbps
# CR =  54.92927840504826 , Bitrate 6711.175 kbps
# CR =  55.08769963575234 , Bitrate 6691.875 kbps
# CR =  55.22138210742736 , Bitrate 6675.675 kbps
# CR =  55.32041013097032 , Bitrate 6663.725 kbps
# CR =  55.460648801128364 , Bitrate 6646.875 kbps
# CR =  55.57770951510469 , Bitrate 6632.875 kbps
# CR =  55.69947305796364 , Bitrate 6618.375 kbps
# CR =  55.7962130499932 , Bitrate 6606.9 kbps
# CR =  55.91045591045591 , Bitrate 6593.4 kbps
# CR =  56.017505470459504 , Bitrate 6580.8 kbps
# CR =  56.11193771428789 , Bitrate 6569.725 kbps
# CR =  56.21847490001564 , Bitrate 6557.275 kbps
# CR =  56.29101403686921 , Bitrate 6548.825 kbps
# CR =  56.39068415618188 , Bitrate 6537.25 kbps
# CR =  56.49092427574265 , Bitrate 6525.65 kbps
# CR =  56.576539245139664 , Bitrate 6515.775 kbps
# CR =  56.65805975654741 , Bitrate 6506.4 kbps
# CR =  56.74025219429042 , Bitrate 6496.975 kbps
# saved i frame 60, Adjusted compression ratio is 56.74025219429042. Target bitrate: 6500.0 kbps, Current bitrate : 6496.975 kbps
# CR =  61.38909820607077 , Bitrate 6292.775 kbps
# saved predicted frame 61, Adjusted compression ratio is 61.38909820607077. Target bitrate: 6500.0 kbps, Current bitrate : 6292.775 kbps
# CR =  59.87720495078454 , Bitrate 6436.4 kbps
# saved predicted frame 62, Adjusted compression ratio is 59.87720495078454. Target bitrate: 6500.0 kbps, Current bitrate : 6436.4 kbps
# CR =  59.005766283448224 , Bitrate 6544.35 kbps
# CR =  59.33986333674049 , Bitrate 6509.175 kbps
# CR =  59.70071905162918 , Bitrate 6471.625 kbps
# saved predicted frame 63, Adjusted compression ratio is 59.70071905162918. Target bitrate: 6500.0 kbps, Current bitrate : 6471.625 kbps
# CR =  58.20983901657201 , Bitrate 6628.025 kbps
# CR =  58.5833303536311 , Bitrate 6587.65 kbps
# CR =  58.97367189655925 , Bitrate 6546.0 kbps
# CR =  59.24330752634599 , Bitrate 6517.55 kbps
# CR =  59.56133618774485 , Bitrate 6484.325 kbps
# saved predicted frame 64, Adjusted compression ratio is 59.56133618774485. Target bitrate: 6500.0 kbps, Current bitrate : 6484.325 kbps
# CR =  57.43576959631051 , Bitrate 6719.525 kbps
# CR =  57.88353889756855 , Bitrate 6669.875 kbps
# CR =  58.331421337869365 , Bitrate 6620.975 kbps
# CR =  58.65207153312542 , Bitrate 6586.425 kbps
# CR =  58.990658692216904 , Bitrate 6550.35 kbps
# CR =  59.26711924083295 , Bitrate 6521.2 kbps
# CR =  59.48420878531286 , Bitrate 6498.5 kbps
# saved predicted frame 65, Adjusted compression ratio is 59.48420878531286. Target bitrate: 6500.0 kbps, Current bitrate : 6498.5 kbps
# CR =  56.883621886862294 , Bitrate 6776.125 kbps
# CR =  57.31900254611179 , Bitrate 6726.9 kbps
# CR =  57.775357236612685 , Bitrate 6676.1 kbps
# CR =  58.11760996373955 , Bitrate 6638.525 kbps
# CR =  58.506624132554045 , Bitrate 6596.35 kbps
# CR =  58.783711056628576 , Bitrate 6566.65 kbps
# CR =  59.03978667264578 , Bitrate 6539.45 kbps
# CR =  59.30239572734475 , Bitrate 6511.8 kbps
# CR =  59.50605326876513 , Bitrate 6490.525 kbps
# saved predicted frame 66, Adjusted compression ratio is 59.50605326876513. Target bitrate: 6500.0 kbps, Current bitrate : 6490.525 kbps
# CR =  56.386587077308974 , Bitrate 6843.9 kbps
# CR =  56.87879465835536 , Bitrate 6787.325 kbps
# CR =  57.379447747719695 , Bitrate 6730.775 kbps
# CR =  57.72876220006338 , Bitrate 6691.9 kbps
# CR =  58.12883616968434 , Bitrate 6647.95 kbps
# CR =  58.41206460123355 , Bitrate 6617.2 kbps
# CR =  58.66747300490968 , Bitrate 6589.725 kbps
# CR =  58.953866328696925 , Bitrate 6559.2 kbps
# CR =  59.180773954294814 , Bitrate 6535.225 kbps
# CR =  59.39005332602991 , Bitrate 6513.275 kbps
# CR =  59.58444119382242 , Bitrate 6493.025 kbps
# saved predicted frame 67, Adjusted compression ratio is 59.58444119382242. Target bitrate: 6500.0 kbps, Current bitrate : 6493.025 kbps
# CR =  56.18141916605702 , Bitrate 6851.225 kbps
# CR =  56.66067229215653 , Bitrate 6795.725 kbps
# CR =  57.16301554134989 , Bitrate 6738.55 kbps
# CR =  57.524947919511185 , Bitrate 6697.975 kbps
# CR =  57.919234530949865 , Bitrate 6654.35 kbps
# CR =  58.208000757916636 , Bitrate 6622.775 kbps
# CR =  58.475070290162535 , Bitrate 6593.85 kbps
# CR =  58.75958365876596 , Bitrate 6563.325 kbps
# CR =  58.97956898068892 , Bitrate 6539.925 kbps
# CR =  59.188850711280914 , Bitrate 6517.825 kbps
# CR =  59.39770877978829 , Bitrate 6495.925 kbps
# saved predicted frame 68, Adjusted compression ratio is 59.39770877978829. Target bitrate: 6500.0 kbps, Current bitrate : 6495.925 kbps
# CR =  55.94333430710104 , Bitrate 6881.225 kbps
# CR =  56.42931219887407 , Bitrate 6824.475 kbps
# CR =  56.944471262459075 , Bitrate 6765.375 kbps
# CR =  57.29561703450414 , Bitrate 6725.7 kbps
# CR =  57.68765819937326 , Bitrate 6681.975 kbps
# CR =  57.9827769257992 , Bitrate 6649.45 kbps
# CR =  58.25514279731828 , Bitrate 6619.725 kbps
# CR =  58.55866946773149 , Bitrate 6586.925 kbps
# CR =  58.79027338657271 , Bitrate 6562.125 kbps
# CR =  59.02537046970195 , Bitrate 6537.15 kbps
# CR =  59.230932994846356 , Bitrate 6515.475 kbps
# CR =  59.40488756032909 , Bitrate 6497.25 kbps
# saved predicted frame 69, Adjusted compression ratio is 59.40488756032909. Target bitrate: 6500.0 kbps, Current bitrate : 6497.25 kbps
# CR =  48.10130711491978 , Bitrate 7663.825 kbps
# CR =  48.67289645588593 , Bitrate 7573.825 kbps
# CR =  49.28276359941714 , Bitrate 7480.1 kbps
# CR =  49.7424427959884 , Bitrate 7410.975 kbps
# CR =  50.2441401258693 , Bitrate 7336.975 kbps
# CR =  50.60694980694981 , Bitrate 7284.375 kbps
# CR =  50.96781329498949 , Bitrate 7232.8 kbps
# CR =  51.35585074148635 , Bitrate 7178.15 kbps
# CR =  51.65955478948144 , Bitrate 7135.95 kbps
# CR =  51.95918137227265 , Bitrate 7094.8 kbps
# CR =  52.23953037705168 , Bitrate 7056.725 kbps
# CR =  52.48945448073328 , Bitrate 7023.125 kbps
# CR =  52.78161577835846 , Bitrate 6984.25 kbps
# CR =  52.98835705045276 , Bitrate 6957.0 kbps
# CR =  53.26417159432017 , Bitrate 6920.975 kbps
# CR =  53.45823937585651 , Bitrate 6895.85 kbps
# CR =  53.646504114732295 , Bitrate 6871.65 kbps
# CR =  53.875045670442056 , Bitrate 6842.5 kbps
# CR =  54.0212999021831 , Bitrate 6823.975 kbps
# CR =  54.1820840789421 , Bitrate 6803.725 kbps
# CR =  54.36286148265033 , Bitrate 6781.1 kbps
# CR =  54.494857476523265 , Bitrate 6764.675 kbps
# CR =  54.69659370374905 , Bitrate 6739.725 kbps
# CR =  54.82287855804408 , Bitrate 6724.2 kbps
# CR =  54.97535623476076 , Bitrate 6705.55 kbps
# CR =  55.10663980895647 , Bitrate 6689.575 kbps
# CR =  55.217866718593214 , Bitrate 6676.1 kbps
# CR =  55.36506792223301 , Bitrate 6658.35 kbps
# CR =  55.47421090252438 , Bitrate 6645.25 kbps
# CR =  55.588185399506145 , Bitrate 6631.625 kbps
# CR =  55.68958615011594 , Bitrate 6619.55 kbps
# CR =  55.81606619678857 , Bitrate 6604.55 kbps
# CR =  55.92635998498069 , Bitrate 6591.525 kbps
# CR =  56.01431355343082 , Bitrate 6581.175 kbps
# CR =  56.12090718447787 , Bitrate 6568.675 kbps
# CR =  56.20154743301445 , Bitrate 6559.25 kbps
# CR =  56.30778042959428 , Bitrate 6546.875 kbps
# CR =  56.39823296551989 , Bitrate 6536.375 kbps
# CR =  56.48659623208168 , Bitrate 6526.15 kbps
# CR =  56.57567095746927 , Bitrate 6515.875 kbps
# CR =  56.66263185197997 , Bitrate 6505.875 kbps
# CR =  56.74287231545367 , Bitrate 6496.675 kbps
# saved i frame 70, Adjusted compression ratio is 56.74287231545367. Target bitrate: 6500.0 kbps, Current bitrate : 6496.675 kbps
# CR =  60.87739144076819 , Bitrate 6363.325 kbps
# saved predicted frame 71, Adjusted compression ratio is 60.87739144076819. Target bitrate: 6500.0 kbps, Current bitrate : 6363.325 kbps
# CR =  59.674384158704335 , Bitrate 6470.65 kbps
# saved predicted frame 72, Adjusted compression ratio is 59.674384158704335. Target bitrate: 6500.0 kbps, Current bitrate : 6470.65 kbps
# CR =  58.54634680896684 , Bitrate 6613.4 kbps
# CR =  58.92465383923756 , Bitrate 6572.975 kbps
# CR =  59.32458420167525 , Bitrate 6530.8 kbps
# CR =  59.624918117635644 , Bitrate 6499.5 kbps
# saved predicted frame 73, Adjusted compression ratio is 59.624918117635644. Target bitrate: 6500.0 kbps, Current bitrate : 6499.5 kbps
# CR =  57.987565329212046 , Bitrate 6653.225 kbps
# CR =  58.39702818942916 , Bitrate 6608.65 kbps
# CR =  58.8235763438715 , Bitrate 6562.875 kbps
# CR =  59.137814175653624 , Bitrate 6529.575 kbps
# CR =  59.46429867647412 , Bitrate 6495.35 kbps
# saved predicted frame 74, Adjusted compression ratio is 59.46429867647412. Target bitrate: 6500.0 kbps, Current bitrate : 6495.35 kbps
# CR =  57.4597174866049 , Bitrate 6706.325 kbps
# CR =  57.882402816868186 , Bitrate 6659.475 kbps
# CR =  58.323807564976235 , Bitrate 6611.275 kbps
# CR =  58.66443874201822 , Bitrate 6574.575 kbps
# CR =  58.9970312637534 , Bitrate 6539.15 kbps
# CR =  59.24568783674649 , Bitrate 6512.925 kbps
# CR =  59.48012972554338 , Bitrate 6488.4 kbps
# saved predicted frame 75, Adjusted compression ratio is 59.48012972554338. Target bitrate: 6500.0 kbps, Current bitrate : 6488.4 kbps
# CR =  57.082246188865 , Bitrate 6743.4 kbps
# CR =  57.527416579862084 , Bitrate 6693.425 kbps
# CR =  57.986653191397345 , Bitrate 6642.675 kbps
# CR =  58.32496103916652 , Bitrate 6605.8 kbps
# CR =  58.67961319590909 , Bitrate 6567.6 kbps
# CR =  58.95080236992974 , Bitrate 6538.7 kbps
# CR =  59.18504960986414 , Bitrate 6513.95 kbps
# CR =  59.45374932464577 , Bitrate 6485.8 kbps
# saved predicted frame 76, Adjusted compression ratio is 59.45374932464577. Target bitrate: 6500.0 kbps, Current bitrate : 6485.8 kbps
# CR =  56.691605600879626 , Bitrate 6802.95 kbps
# CR =  57.15681144252568 , Bitrate 6750.025 kbps
# CR =  57.60810113922264 , Bitrate 6699.5 kbps
# CR =  57.968872237794386 , Bitrate 6659.675 kbps
# CR =  58.3452696553634 , Bitrate 6618.65 kbps
# CR =  58.643207686739906 , Bitrate 6586.55 kbps
# CR =  58.912176685391024 , Bitrate 6557.85 kbps
# CR =  59.18790039015462 , Bitrate 6528.7 kbps
# CR =  59.40034079785368 , Bitrate 6506.425 kbps
# CR =  59.597445638994415 , Bitrate 6485.9 kbps
# saved predicted frame 77, Adjusted compression ratio is 59.597445638994415. Target bitrate: 6500.0 kbps, Current bitrate : 6485.9 kbps
# CR =  56.41204173058748 , Bitrate 6811.875 kbps
# CR =  56.88713311317548 , Bitrate 6757.3 kbps
# CR =  57.37833136826869 , Bitrate 6701.825 kbps
# CR =  57.7411952665502 , Bitrate 6661.45 kbps
# CR =  58.14167143110618 , Bitrate 6617.475 kbps
# CR =  58.426414242072454 , Bitrate 6586.575 kbps
# CR =  58.69783290607142 , Bitrate 6557.4 kbps
# CR =  58.97815357294277 , Bitrate 6527.55 kbps
# CR =  59.19740497486876 , Bitrate 6504.4 kbps
# CR =  59.39938367338718 , Bitrate 6483.225 kbps
# saved predicted frame 78, Adjusted compression ratio is 59.39938367338718. Target bitrate: 6500.0 kbps, Current bitrate : 6483.225 kbps
# CR =  56.11834418611729 , Bitrate 6843.475 kbps
# CR =  56.61868321321469 , Bitrate 6785.425 kbps
# CR =  57.15370989810034 , Bitrate 6724.475 kbps
# CR =  57.51799192557481 , Bitrate 6683.625 kbps
# CR =  57.92014454897186 , Bitrate 6639.125 kbps
# CR =  58.213515882227526 , Bitrate 6607.05 kbps
# CR =  58.463246372214755 , Bitrate 6580.0 kbps
# CR =  58.75677398788653 , Bitrate 6548.5 kbps
# CR =  58.98122037559251 , Bitrate 6524.625 kbps
# CR =  59.18599983944771 , Bitrate 6503.0 kbps
# CR =  59.38550883396494 , Bitrate 6482.075 kbps
# saved predicted frame 79, Adjusted compression ratio is 59.38550883396494. Target bitrate: 6500.0 kbps, Current bitrate : 6482.075 kbps
# CR =  48.25651984671122 , Bitrate 7639.175 kbps
# CR =  48.836516105955525 , Bitrate 7548.45 kbps
# CR =  49.43327533666564 , Bitrate 7457.325 kbps
# CR =  49.882107784269124 , Bitrate 7390.225 kbps
# CR =  50.38491896712559 , Bitrate 7316.475 kbps
# CR =  50.7667201454255 , Bitrate 7261.45 kbps
# CR =  51.11906148598051 , Bitrate 7211.4 kbps
# CR =  51.48926957699853 , Bitrate 7159.55 kbps
# CR =  51.80092672285087 , Bitrate 7116.475 kbps
# CR =  52.092260842839316 , Bitrate 7076.675 kbps
# CR =  52.349136247772314 , Bitrate 7041.95 kbps
# CR =  52.59898694442464 , Bitrate 7008.5 kbps
# CR =  52.89009566100069 , Bitrate 6969.925 kbps
# CR =  53.105912181629584 , Bitrate 6941.6 kbps
# CR =  53.387400434467786 , Bitrate 6905.0 kbps
# CR =  53.57613896892384 , Bitrate 6880.675 kbps
# CR =  53.74759886130441 , Bitrate 6858.725 kbps
# CR =  53.97858515603553 , Bitrate 6829.375 kbps
# CR =  54.12699228414323 , Bitrate 6810.65 kbps
# CR =  54.286008806161355 , Bitrate 6790.7 kbps
# CR =  54.469091110577565 , Bitrate 6767.875 kbps
# CR =  54.59836933581163 , Bitrate 6751.85 kbps
# CR =  54.792932389498866 , Bitrate 6727.875 kbps
# CR =  54.92641389252068 , Bitrate 6711.525 kbps
# CR =  55.076382923094165 , Bitrate 6693.25 kbps
# CR =  55.21021712514179 , Bitrate 6677.025 kbps
# CR =  55.31874983587 , Bitrate 6663.925 kbps
# CR =  55.45585149192545 , Bitrate 6647.45 kbps
# CR =  55.567028179947656 , Bitrate 6634.15 kbps
# CR =  55.682646375771775 , Bitrate 6620.375 kbps
# CR =  55.78755812149805 , Bitrate 6607.925 kbps
# CR =  55.916180335142144 , Bitrate 6592.725 kbps
# CR =  56.023464688986486 , Bitrate 6580.1 kbps
# CR =  56.11727633922455 , Bitrate 6569.1 kbps
# CR =  56.21461711187953 , Bitrate 6557.725 kbps
# CR =  56.29402265412939 , Bitrate 6548.475 kbps
# CR =  56.39478183048981 , Bitrate 6536.775 kbps
# CR =  56.49611880368737 , Bitrate 6525.05 kbps
# CR =  56.587395090202236 , Bitrate 6514.525 kbps
# CR =  56.68877227380197 , Bitrate 6502.875 kbps
# CR =  56.78701403731736 , Bitrate 6491.625 kbps
# saved i frame 80, Adjusted compression ratio is 56.78701403731736. Target bitrate: 6500.0 kbps, Current bitrate : 6491.625 kbps
# CR =  62.06635294513804 , Bitrate 6216.8 kbps
# saved predicted frame 81, Adjusted compression ratio is 62.06635294513804. Target bitrate: 6500.0 kbps, Current bitrate : 6216.8 kbps
# CR =  60.6315789473684 , Bitrate 6324.925 kbps
# saved predicted frame 82, Adjusted compression ratio is 60.6315789473684. Target bitrate: 6500.0 kbps, Current bitrate : 6324.925 kbps
# CR =  59.3943592759379 , Bitrate 6479.1 kbps
# saved predicted frame 83, Adjusted compression ratio is 59.3943592759379. Target bitrate: 6500.0 kbps, Current bitrate : 6479.1 kbps
# CR =  59.14232083553931 , Bitrate 6473.6 kbps
# saved predicted frame 84, Adjusted compression ratio is 59.14232083553931. Target bitrate: 6500.0 kbps, Current bitrate : 6473.6 kbps
# CR =  58.58146843006465 , Bitrate 6574.625 kbps
# CR =  58.96376744948593 , Bitrate 6533.825 kbps
# CR =  59.3494167934507 , Bitrate 6493.2 kbps
# saved predicted frame 85, Adjusted compression ratio is 59.3494167934507. Target bitrate: 6500.0 kbps, Current bitrate : 6493.2 kbps
# CR =  58.090135518436774 , Bitrate 6585.675 kbps
# CR =  58.49061094318965 , Bitrate 6542.225 kbps
# CR =  58.88135958694878 , Bitrate 6500.4 kbps
# CR =  59.19241468731057 , Bitrate 6467.5 kbps
# saved predicted frame 86, Adjusted compression ratio is 59.19241468731057. Target bitrate: 6500.0 kbps, Current bitrate : 6467.5 kbps
# CR =  57.57458621780228 , Bitrate 6644.625 kbps
# CR =  58.01539932406645 , Bitrate 6595.975 kbps
# CR =  58.43891806202316 , Bitrate 6549.925 kbps
# CR =  58.767077428302684 , Bitrate 6514.7 kbps
# CR =  59.10960386752288 , Bitrate 6478.35 kbps
# saved predicted frame 87, Adjusted compression ratio is 59.10960386752288. Target bitrate: 6500.0 kbps, Current bitrate : 6478.35 kbps
# CR =  57.28337509469143 , Bitrate 6661.4 kbps
# CR =  57.727406189441524 , Bitrate 6611.9 kbps
# CR =  58.17286639129868 , Bitrate 6563.0 kbps
# CR =  58.50639199473087 , Bitrate 6526.875 kbps
# CR =  58.85480278755658 , Bitrate 6489.575 kbps
# saved predicted frame 88, Adjusted compression ratio is 58.85480278755658. Target bitrate: 6500.0 kbps, Current bitrate : 6489.575 kbps
# CR =  56.97219313734201 , Bitrate 6696.975 kbps
# CR =  57.44471974194753 , Bitrate 6643.75 kbps
# CR =  57.90035810768361 , Bitrate 6593.25 kbps
# CR =  58.23443689255203 , Bitrate 6556.725 kbps
# CR =  58.596832839913354 , Bitrate 6517.575 kbps
# CR =  58.8764224396087 , Bitrate 6487.7 kbps
# saved predicted frame 89, Adjusted compression ratio is 58.8764224396087. Target bitrate: 6500.0 kbps, Current bitrate : 6487.7 kbps
# CR =  48.38509622483633 , Bitrate 7618.875 kbps
# CR =  48.96284022725531 , Bitrate 7528.975 kbps
# CR =  49.55105113178133 , Bitrate 7439.6 kbps
# CR =  50.00746096558461 , Bitrate 7371.7 kbps
# CR =  50.496554936098505 , Bitrate 7300.3 kbps
# CR =  50.87952962934851 , Bitrate 7245.35 kbps
# CR =  51.207467755714354 , Bitrate 7198.95 kbps
# CR =  51.60874845565049 , Bitrate 7142.975 kbps
# CR =  51.897553576016506 , Bitrate 7103.225 kbps
# CR =  52.18905507853697 , Bitrate 7063.55 kbps
# CR =  52.46517585525962 , Bitrate 7026.375 kbps
# CR =  52.705397928327876 , Bitrate 6994.35 kbps
# CR =  53.005690375967404 , Bitrate 6954.725 kbps
# CR =  53.215154424130425 , Bitrate 6927.35 kbps
# CR =  53.46890082276024 , Bitrate 6894.475 kbps
# CR =  53.6568502945639 , Bitrate 6870.325 kbps
# CR =  53.82627359936921 , Bitrate 6848.7 kbps
# CR =  54.04822907159585 , Bitrate 6820.575 kbps
# CR =  54.202398850198655 , Bitrate 6801.175 kbps
# CR =  54.35143991360149 , Bitrate 6782.525 kbps
# CR =  54.520245063059 , Bitrate 6761.525 kbps
# CR =  54.657261576897014 , Bitrate 6744.575 kbps
# CR =  54.859387846972915 , Bitrate 6719.725 kbps
# CR =  54.97351163735736 , Bitrate 6705.775 kbps
# CR =  55.138373175684016 , Bitrate 6685.725 kbps
# CR =  55.26650150482181 , Bitrate 6670.225 kbps
# CR =  55.37026536842542 , Bitrate 6657.725 kbps
# CR =  55.51890841729543 , Bitrate 6639.9 kbps
# CR =  55.62635099195347 , Bitrate 6627.075 kbps
# CR =  55.735895555673125 , Bitrate 6614.05 kbps
# CR =  55.82768895266294 , Bitrate 6603.175 kbps
# CR =  55.95182533268067 , Bitrate 6588.525 kbps
# CR =  56.062017390114185 , Bitrate 6575.575 kbps
# CR =  56.15766923736074 , Bitrate 6564.375 kbps
# CR =  56.26008691438666 , Bitrate 6552.425 kbps
# CR =  56.332733544978375 , Bitrate 6543.975 kbps
# CR =  56.433415489184526 , Bitrate 6532.3 kbps
# CR =  56.53922692607062 , Bitrate 6520.075 kbps
# CR =  56.61846581528044 , Bitrate 6510.95 kbps
# CR =  56.70904769596417 , Bitrate 6500.55 kbps
# CR =  56.79248189801261 , Bitrate 6491.0 kbps
# saved i frame 90, Adjusted compression ratio is 56.79248189801261. Target bitrate: 6500.0 kbps, Current bitrate : 6491.0 kbps
# CR =  63.019693654266945 , Bitrate 6080.5 kbps
# saved predicted frame 91, Adjusted compression ratio is 63.019693654266945. Target bitrate: 6500.0 kbps, Current bitrate : 6080.5 kbps
# CR =  62.14508780876356 , Bitrate 6154.225 kbps
# saved predicted frame 92, Adjusted compression ratio is 62.14508780876356. Target bitrate: 6500.0 kbps, Current bitrate : 6154.225 kbps
# CR =  61.26972123307305 , Bitrate 6256.05 kbps
# saved predicted frame 93, Adjusted compression ratio is 61.26972123307305. Target bitrate: 6500.0 kbps, Current bitrate : 6256.05 kbps
# CR =  60.43452066247801 , Bitrate 6320.425 kbps
# saved predicted frame 94, Adjusted compression ratio is 60.43452066247801. Target bitrate: 6500.0 kbps, Current bitrate : 6320.425 kbps
# CR =  59.59816827461325 , Bitrate 6419.3 kbps
# saved predicted frame 95, Adjusted compression ratio is 59.59816827461325. Target bitrate: 6500.0 kbps, Current bitrate : 6419.3 kbps
# CR =  58.973200180771755 , Bitrate 6465.575 kbps
# saved predicted frame 96, Adjusted compression ratio is 58.973200180771755. Target bitrate: 6500.0 kbps, Current bitrate : 6465.575 kbps
# CR =  58.910058448225534 , Bitrate 6479.9 kbps
# saved predicted frame 97, Adjusted compression ratio is 58.910058448225534. Target bitrate: 6500.0 kbps, Current bitrate : 6479.9 kbps
# CR =  58.550298794893685 , Bitrate 6516.8 kbps
# CR =  58.96140973813318 , Bitrate 6472.9 kbps
# saved predicted frame 98, Adjusted compression ratio is 58.96140973813318. Target bitrate: 6500.0 kbps, Current bitrate : 6472.9 kbps
# CR =  58.02727111740743 , Bitrate 6568.875 kbps
# CR =  58.470432889618515 , Bitrate 6520.725 kbps
# CR =  58.940434410699545 , Bitrate 6470.45 kbps
# saved predicted frame 99, Adjusted compression ratio is 58.940434410699545. Target bitrate: 6500.0 kbps, Current bitrate : 6470.45 kbps
# finished the process. Total number of frames = 100

# %%
# Define the codec and create a VideoWriter object
fourcc = cv2.VideoWriter_fourcc(*'H264')
out = cv2.VideoWriter('Adjusted_reconstructed_video.mp4', fourcc, fps, (width, height), isColor=False)  # isColor=False for grayscale video

# Write each frame to the video
for frame in adjust_video_arr:
    out.write(frame)

# Release the VideoWriter object
out.release()

# %% [markdown]
# <font size="5">Method 2: Compress each frames using Intra prediction (By taking the average of neiboring pixels) - Additional code</font>

# %%
# Read the video
video_path = 'input_video.mp4'
cap = cv2.VideoCapture(video_path)

fps = cap.get(cv2.CAP_PROP_FPS)
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

# Create a folder to save frames
output_folder7 = 'intra_predicted'
os.makedirs(output_folder7, exist_ok=True)

# Create a folder to save frames
output_folder9 = 'intra_residual'
os.makedirs(output_folder9, exist_ok=True)

# Create a folder to save frames
output_folder10 = 'intra_text'
os.makedirs(output_folder10, exist_ok=True)

# Create a folder to save frames
output_folder11 = 'intra_reconstructed'
os.makedirs(output_folder11, exist_ok=True)

# Set the block size for macroblock search
block_size = 8
frame_counter = 0

while True:
    # Read the current frame
    ret, curr_frame = cap.read()
    if not ret:
        print('Finished the process. Total number of frames =',frame_counter)
        break
    # convert to gray scale
    curr_frame_gray = cv2.cvtColor(curr_frame, cv2.COLOR_BGR2GRAY)

    # Encoding intra predicted frame
    intra_predicted_result = intra_predict(curr_frame_gray,height,width)
    cv2.imwrite(os.path.join(output_folder7, f'intra_predicted_frame_{frame_counter}.png'), intra_predicted_result)
    output_file_path_intra_pred = os.path.join(output_folder10, f'intra_text_predicted{frame_counter}.txt')
    prob_intra_pred,huffman_mappings_intra_pred,encoded_intra_pred = encode_frames(intra_predicted_result, block_size=8, quantization_matrix = quantization_matrix, output_file_path=output_file_path_intra_pred)

    # Encoding intra residual frame
    residual_intra = cv2.absdiff(curr_frame_gray, intra_predicted_result)
    cv2.imwrite(os.path.join(output_folder9, f'intra_residual_frame_{frame_counter}.png'), residual_intra)
    output_file_path_intra_res = os.path.join(output_folder10, f'intra_text_residual{frame_counter}.txt')
    prob_intra_res,huffman_mappings_intra_res,encoded_intra_res= encode_frames(residual_intra, block_size=8, quantization_matrix = quantization_matrix, output_file_path=output_file_path_intra_res)
            
    # Decoding Transmitted files
    processed_frame_intra_pred = decode_frames(output_file_path_intra_pred,huffman_mappings_intra_pred, block_size, height,width, quantization_matrix)  # Decoded predicted
    processed_frame_intra_res = decode_frames(output_file_path_intra_res,huffman_mappings_intra_res, block_size, height,width, quantization_matrix)  # Decoded residual     
    
    # reconstruct the image
    predicted_intra_frame = intra_predicted_result + processed_frame_intra_res
    # save the reconstructed image
    cv2.imwrite(os.path.join(output_folder11, f'reconstructed_intra_{frame_counter}.png'), predicted_intra_frame)

    # Calculate average length and compression ratio
    average_len_intra_pred = calculate_average_length(prob_intra_pred, huffman_mappings_intra_pred)
    average_len_intra_res = calculate_average_length(prob_intra_res, huffman_mappings_intra_res)
    # calculate compression ratio
    cr_pred = compression_ratio(height, width, average_len_intra_pred)  # Compression ratio for predicted frames
    cr_res = compression_ratio(height, width, average_len_intra_res)  # Compression ratio for residual frames
    # calculate bitrate
    current_bitrate_intra = (len(encoded_intra_pred)+len(encoded_intra_res))*fps

    print(f'Saved frame {frame_counter}, CR_predict = {cr_pred} , CR_residual = {cr_res}, Bitrate {current_bitrate_intra/1000} kbps')

    frame_counter += 1
    
# Release the video capture and close the window
cap.release()
cv2.destroyAllWindows()
# Out:
# Saved frame 0, CR_predict = 43.86730568422181 , CR_residual = 44.864044201988015, Bitrate 16620.35 kbps
# Saved frame 1, CR_predict = 43.897864587519734 , CR_residual = 44.90038275676223, Bitrate 16607.85 kbps
# Saved frame 2, CR_predict = 43.85712883566962 , CR_residual = 44.89108760179619, Bitrate 16617.35 kbps
# Saved frame 3, CR_predict = 43.92898957008244 , CR_residual = 44.97584305304769, Bitrate 16588.125 kbps
# Saved frame 4, CR_predict = 43.98323664076596 , CR_residual = 45.00659276261175, Bitrate 16572.175 kbps
# Saved frame 5, CR_predict = 44.00358102059089 , CR_residual = 45.00439496044537, Bitrate 16568.7 kbps
# Saved frame 6, CR_predict = 43.978776518167926 , CR_residual = 44.99684165234984, Bitrate 16574.8 kbps
# Saved frame 7, CR_predict = 44.02184134869432 , CR_residual = 45.02335806540257, Bitrate 16561.775 kbps
# Saved frame 8, CR_predict = 43.96042083421529 , CR_residual = 44.959798520000156, Bitrate 16585.05 kbps
# Saved frame 9, CR_predict = 43.95871715527571 , CR_residual = 45.010027258269865, Bitrate 16576.225 kbps
# Saved frame 10, CR_predict = 43.99176586413677 , CR_residual = 45.002609404231855, Bitrate 16571.275 kbps
# Saved frame 11, CR_predict = 44.010541804582616 , CR_residual = 45.033120672858175, Bitrate 16562.15 kbps
# Saved frame 12, CR_predict = 43.98087528670666 , CR_residual = 45.028307590831645, Bitrate 16568.675 kbps
# Saved frame 13, CR_predict = 44.01435146768231 , CR_residual = 45.03380834000138, Bitrate 16561.3 kbps
# Saved frame 14, CR_predict = 43.99307834596335 , CR_residual = 44.9940956234381, Bitrate 16572.575 kbps
# Saved frame 15, CR_predict = 44.01816179038715 , CR_residual = 45.11938019601424, Bitrate 16545.05 kbps
# Saved frame 16, CR_predict = 44.0825112107623 , CR_residual = 45.140236697258956, Bitrate 16529.05 kbps
# Saved frame 17, CR_predict = 44.06696591336986 , CR_residual = 45.12849391119123, Bitrate 16534.125 kbps
# Saved frame 18, CR_predict = 44.086333344295895 , CR_residual = 45.18768444374984, Bitrate 16519.75 kbps
# Saved frame 19, CR_predict = 44.15193997137501 , CR_residual = 45.24647509167064, Bitrate 16496.725 kbps
# Saved frame 20, CR_predict = 44.131194052632054 , CR_residual = 45.216228730532094, Bitrate 16506.1 kbps
# Saved frame 21, CR_predict = 44.12511932299352 , CR_residual = 45.236342217641045, Bitrate 16503.625 kbps
# Saved frame 22, CR_predict = 44.20886000047971 , CR_residual = 45.31920386511441, Bitrate 16472.9 kbps
# Saved frame 23, CR_predict = 44.27948542394867 , CR_residual = 45.393284714675815, Bitrate 16446.325 kbps
# Saved frame 24, CR_predict = 44.32167600955831 , CR_residual = 45.42908637182869, Bitrate 16432.0 kbps
# Saved frame 25, CR_predict = 44.286267761089135 , CR_residual = 45.449669890703326, Bitrate 16434.975 kbps
# Saved frame 26, CR_predict = 44.26871774549449 , CR_residual = 45.43412550955329, Bitrate 16441.05 kbps
# Saved frame 27, CR_predict = 44.295047988104336 , CR_residual = 45.448128981750614, Bitrate 16433.6 kbps
# Saved frame 28, CR_predict = 44.23724237242371 , CR_residual = 45.369960124058494, Bitrate 16458.45 kbps
# Saved frame 29, CR_predict = 44.207004478981155 , CR_residual = 45.30722858248997, Bitrate 16475.4 kbps
# Saved frame 30, CR_predict = 44.12406301898648 , CR_residual = 45.229543244677444, Bitrate 16505.05 kbps
# Saved frame 31, CR_predict = 44.18501516222988 , CR_residual = 45.297625081790464, Bitrate 16481.275 kbps
# Saved frame 32, CR_predict = 44.12749619193257 , CR_residual = 45.20361491581955, Bitrate 16509.075 kbps
# Saved frame 33, CR_predict = 44.16675153207012 , CR_residual = 45.25966850828727, Bitrate 16491.55 kbps
# Saved frame 34, CR_predict = 44.12511932299346 , CR_residual = 45.20555504460592, Bitrate 16509.175 kbps
# Saved frame 35, CR_predict = 44.103211372751936 , CR_residual = 45.231208110305076, Bitrate 16508.7 kbps
# Saved frame 36, CR_predict = 44.04287920286977 , CR_residual = 45.10792423278355, Bitrate 16542.425 kbps
# Saved frame 37, CR_predict = 44.107037096861035 , CR_residual = 45.17854680821729, Bitrate 16517.475 kbps
# Saved frame 38, CR_predict = 44.09213370929979 , CR_residual = 45.13968395853874, Bitrate 16527.325 kbps
# Saved frame 39, CR_predict = 44.09081531050692 , CR_residual = 45.183115163994735, Bitrate 16519.725 kbps
# Saved frame 40, CR_predict = 44.070917068155445 , CR_residual = 45.155995443242645, Bitrate 16528.4 kbps
# Saved frame 41, CR_predict = 44.14030928390539 , CR_residual = 45.221775491991075, Bitrate 16503.375 kbps
# Saved frame 42, CR_predict = 44.125383406897576 , CR_residual = 45.214842252769635, Bitrate 16507.45 kbps
# Saved frame 43, CR_predict = 44.16489954354312 , CR_residual = 45.27050675115593, Bitrate 16489.95 kbps
# Saved frame 44, CR_predict = 44.172176106356375 , CR_residual = 45.252029276825596, Bitrate 16491.9 kbps
# Saved frame 45, CR_predict = 44.18739848848988 , CR_residual = 45.2794035460514, Bitrate 16484.1 kbps
# Saved frame 46, CR_predict = 44.2096552716632 , CR_residual = 45.2620302471277, Bitrate 16483.025 kbps
# Saved frame 47, CR_predict = 44.19388773500931 , CR_residual = 45.25341803618286, Bitrate 16487.55 kbps
# Saved frame 48, CR_predict = 44.11482251574395 , CR_residual = 45.227462334985546, Bitrate 16507.175 kbps
# Saved frame 49, CR_predict = 44.246268701502125 , CR_residual = 45.323104160519335, Bitrate 16465.15 kbps
# Saved frame 50, CR_predict = 44.108092585834555 , CR_residual = 45.177577881810834, Bitrate 16517.45 kbps
# Saved frame 51, CR_predict = 44.13713834162461 , CR_residual = 45.232873098502125, Bitrate 16501.975 kbps
# Saved frame 52, CR_predict = 44.12115844371901 , CR_residual = 45.21387176892652, Bitrate 16508.425 kbps
# Saved frame 53, CR_predict = 44.19070909041871 , CR_residual = 45.27523273808064, Bitrate 16484.225 kbps
# Saved frame 54, CR_predict = 44.16066701007462 , CR_residual = 45.267588252088366, Bitrate 16491.275 kbps
# Saved frame 55, CR_predict = 44.228219725373286 , CR_residual = 45.29442481953616, Bitrate 16473.7 kbps
# Saved frame 56, CR_predict = 44.182234939849266 , CR_residual = 45.20694095284813, Bitrate 16498.125 kbps
# Saved frame 57, CR_predict = 44.2276890960462 , CR_residual = 45.29665104105871, Bitrate 16473.4 kbps
# Saved frame 58, CR_predict = 44.093188485104015 , CR_residual = 45.11399654889673, Bitrate 16531.775 kbps
# Saved frame 59, CR_predict = 44.21111334314763 , CR_residual = 45.2803768451502, Bitrate 16479.45 kbps
# Saved frame 60, CR_predict = 44.11970629948119 , CR_residual = 45.15862297070097, Bitrate 16518.675 kbps
# Saved frame 61, CR_predict = 44.19852407814832 , CR_residual = 45.26147452169667, Bitrate 16485.225 kbps
# Saved frame 62, CR_predict = 44.219996401367496 , CR_residual = 45.25272364584931, Bitrate 16482.75 kbps
# Saved frame 63, CR_predict = 44.138195271762896 , CR_residual = 45.11855185898005, Bitrate 16522.425 kbps
# Saved frame 64, CR_predict = 44.09806747970884 , CR_residual = 45.06656560593652, Bitrate 16539.45 kbps
# Saved frame 65, CR_predict = 44.085937920436265 , CR_residual = 45.01057682621957, Bitrate 16551.925 kbps
# Saved frame 66, CR_predict = 43.971563528794306 , CR_residual = 44.869504888431756, Bitrate 16599.425 kbps
# Saved frame 67, CR_predict = 44.00555083038632 , CR_residual = 44.942532589249005, Bitrate 16579.6 kbps
# Saved frame 68, CR_predict = 44.01067316129726 , CR_residual = 44.93445230651091, Bitrate 16580.1 kbps
# Saved frame 69, CR_predict = 44.040774512644234 , CR_residual = 44.94965660408419, Bitrate 16571.6 kbps
# Saved frame 70, CR_predict = 43.943651898187184 , CR_residual = 44.82994500232577, Bitrate 16612.0 kbps
# Saved frame 71, CR_predict = 44.15365866074182 , CR_residual = 45.055824782903606, Bitrate 16530.875 kbps
# Saved frame 72, CR_predict = 44.03603969503039 , CR_residual = 44.980096087851756, Bitrate 16566.95 kbps
# Saved frame 73, CR_predict = 44.20064387331165 , CR_residual = 45.165400637098784, Bitrate 16502.15 kbps
# Saved frame 74, CR_predict = 44.202498860883935 , CR_residual = 45.208188342924416, Bitrate 16494.075 kbps
# Saved frame 75, CR_predict = 44.1625186436414 , CR_residual = 45.15945277974295, Bitrate 16510.425 kbps
# Saved frame 76, CR_predict = 44.08211585546319 , CR_residual = 45.047290857101004, Bitrate 16545.975 kbps
# Saved frame 77, CR_predict = 44.11125935587319 , CR_residual = 45.07676035240673, Bitrate 16535.1 kbps
# Saved frame 78, CR_predict = 44.105058191182955 , CR_residual = 45.01195080480965, Bitrate 16548.05 kbps
# Saved frame 79, CR_predict = 44.14004502131328 , CR_residual = 45.11261633349854, Bitrate 16523.15 kbps
# Saved frame 80, CR_predict = 44.15603860539076 , CR_residual = 45.09771538673273, Bitrate 16522.825 kbps
# Saved frame 81, CR_predict = 44.21071567775012 , CR_residual = 45.17979263181117, Bitrate 16497.65 kbps
# Saved frame 82, CR_predict = 44.16780988096594 , CR_residual = 45.1430005939224, Bitrate 16512.4 kbps
# Saved frame 83, CR_predict = 44.21456007628164 , CR_residual = 45.17522494784152, Bitrate 16497.75 kbps
# Saved frame 84, CR_predict = 44.21005291798461 , CR_residual = 45.175363348937545, Bitrate 16498.575 kbps
# Saved frame 85, CR_predict = 44.28852900187419 , CR_residual = 45.329652594398375, Bitrate 16456.025 kbps
# Saved frame 86, CR_predict = 44.30662724453739 , CR_residual = 45.33104612234737, Bitrate 16452.375 kbps
# Saved frame 87, CR_predict = 44.3873173932806 , CR_residual = 45.4411261667987, Bitrate 16417.55 kbps
# Saved frame 88, CR_predict = 44.32767172704042 , CR_residual = 45.41369593002663, Bitrate 16433.625 kbps
# Saved frame 89, CR_predict = 44.36648323048269 , CR_residual = 45.46676698035248, Bitrate 16416.875 kbps
# Saved frame 90, CR_predict = 44.321409570870806 , CR_residual = 45.374986152653186, Bitrate 16441.725 kbps
# Saved frame 91, CR_predict = 44.39573673752032 , CR_residual = 45.49159465537933, Bitrate 16406.975 kbps
# Saved frame 92, CR_predict = 44.393865496125294 , CR_residual = 45.43986588928471, Bitrate 16416.55 kbps
# Saved frame 93, CR_predict = 44.447927656367746 , CR_residual = 45.55990520711997, Bitrate 16385.075 kbps
# Saved frame 94, CR_predict = 44.44980345817155 , CR_residual = 45.52010273634301, Bitrate 16391.8 kbps
# Saved frame 95, CR_predict = 44.49366191020761 , CR_residual = 45.629691977299075, Bitrate 16364.175 kbps
# Saved frame 96, CR_predict = 44.45154541590422 , CR_residual = 45.5711694115393, Bitrate 16382.4 kbps
# Saved frame 97, CR_predict = 44.484802775473256 , CR_residual = 45.62263310314102, Bitrate 16367.075 kbps
# Saved frame 98, CR_predict = 44.45315349807512 , CR_residual = 45.53387805013621, Bitrate 16388.725 kbps
# Saved frame 99, CR_predict = 44.4413635966353 , CR_residual = 45.579057669303346, Bitrate 16382.9 kbps
# Finished the process. Total number of frames = 100
